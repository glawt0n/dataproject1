# %% [markdown]
# Math 5750/6880: Mathematics of Data Science \\
# Project 1

# %% [markdown]
# # 3. Python and Google Colab
# Project Euler Problem
# https://projecteuler.net/

# %%
def main():
	_stack_9 = 0;next_instruction_state = 0;_stack_pointer = 0;_stack_57 = 0;_stack_26 = 0;_stack_47 = 0;_stack_44 = 0;_pc_stack_7 = 0;_flag_equal = 0;_stack_21 = 0;_stack_16 = 0;_stack_24 = 0;_stack_43 = 0;_stack_13 = 0;_stack_4 = 0;_stack_3 = 0;_stack_36 = 0;_stack_64 = 0;ERROR_SUBTRACT_UNDERFLOW = 0;_stack_32 = 0;_next_var_pointer = 0;ERROR_PC_STACK_UNDERFLOW = 0;_stack_46 = 0;_stack_28 = 0;ERROR_BELOW_BOUNDS = 0;_stack_35 = 0;ERROR_VAR_POINTER_UNDERFLOW = 0;_stack_17 = 0;arg_one = 0;_stack_29 = 0;_stack_37 = 0;_pc_stack_4 = 0;current_instruction = 0;_stack_50 = 0;_stack_41 = 0;_stack_30 = 0;_stack_54 = 0;_holder_two = 0;arg_two = 0;_stack_7 = 0;var_pointer = 0;_stack_19 = 0;_pc_stack_14 = 0;_stack_61 = 0;ERROR_PC_STACK_OVERFLOW = 0;jump_arg = 0;_stack_58 = 0;_stack_22 = 0;ERROR_STACK_UNDERFLOW = 0;_pc_stack_1 = 0;current_pc = 0;_stack_53 = 0;_stack_40 = 0;_pc_stack_6 = 0;_pc_stack_pointer = 0;_pc_stack_12 = 0;_stack_14 = 0;ERROR_STACK_OVERFLOW = 0;_stack_38 = 0;_stack_62 = 0;_stack_48 = 0;_pc_stack_10 = 0;_pc_stack_11 = 0;_stack_6 = 0;_stack_20 = 0;_pc_stack_5 = 0;_pc_stack_15 = 0;stack_frame = 0;_stack_56 = 0;_stack_2 = 0;_stack_12 = 0;_next_stack_pointer = 0;instruction_state = 0;_stack_31 = 0;next_pc = 0;_stack_52 = 0;ERROR_DIVIDE_BY_ZERO = 0;_next_pc_stack_pointer = 0;_holder_one = 0;_pc_stack_9 = 0;_stack_1 = 0;_holder = 0;_stack_5 = 0;_stack_8 = 0;_stack_60 = 0;_stack_11 = 0;_stack_42 = 0;_stack_18 = 0;_pc_stack_13 = 0;_stack_15 = 0;_stack_49 = 0;_pc_stack_3 = 0;_stack_33 = 0;_stack_34 = 0;_stack_55 = 0;_stack_23 = 0;_stack_25 = 0;_stack_59 = 0;_stack_51 = 0;_stack_45 = 0;_pc_stack_8 = 0;_stack_39 = 0;_stack_10 = 0;var_pointer_offset = 0;ERROR_ABOVE_BOUNDS = 0;ERROR_DECREMENT_UNDERFLOW = 0;_pc_stack_2 = 0;next_instruction = 0;_stack_27 = 0;_stack_63 = 0;

	current_pc = 91;

	while (True):
		if (next_instruction >= 1 ):
			next_instruction -= 1;
			current_instruction += 1;
		elif (next_instruction_state >= 1 ):
			next_instruction_state -= 1;
			instruction_state += 1;
		elif (_next_stack_pointer >= 1 ):
			_next_stack_pointer -= 1;
			_stack_pointer += 1;
		elif (_next_pc_stack_pointer >= 1 ):
			_next_pc_stack_pointer -= 1;
			_pc_stack_pointer += 1;
		elif (_next_var_pointer >= 1 ):
			_next_var_pointer -= 1;
			var_pointer += 1;
		elif (instruction_state >= 1 and _stack_pointer >= 64 and current_instruction >= 38 and _stack_64 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 64; current_instruction -= 38; _stack_64 -= 1;
			next_instruction_state += 1; _next_stack_pointer += 64; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 64 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 64; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 63;
		elif (instruction_state >= 1 and _stack_pointer >= 63 and current_instruction >= 38 and _stack_63 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 63; current_instruction -= 38; _stack_63 -= 1;
			next_instruction_state += 1; _next_stack_pointer += 63; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 63 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 63; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 62;
		elif (_stack_62 >= 1 and _stack_pointer >= 62 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_62 -= 1; _stack_pointer -= 62; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 62; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 62 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 62; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 61;
		elif (_stack_61 >= 1 and _stack_pointer >= 61 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_61 -= 1; _stack_pointer -= 61; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 61; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 61 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 61; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 60;
		elif (_stack_60 >= 1 and _stack_pointer >= 60 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_60 -= 1; _stack_pointer -= 60; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 60; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 60 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 60; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 59;
		elif (_stack_59 >= 1 and _stack_pointer >= 59 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_59 -= 1; _stack_pointer -= 59; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 59; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 59 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 59; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 58;
		elif (_stack_58 >= 1 and _stack_pointer >= 58 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_58 -= 1; _stack_pointer -= 58; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 58; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 58 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 58; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 57;
		elif (_stack_57 >= 1 and _stack_pointer >= 57 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_57 -= 1; _stack_pointer -= 57; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 57; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 57 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 57; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 56;
		elif (_stack_56 >= 1 and _stack_pointer >= 56 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_56 -= 1; _stack_pointer -= 56; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 56; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 56 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 56; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 55;
		elif (_stack_55 >= 1 and _stack_pointer >= 55 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_55 -= 1; _stack_pointer -= 55; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 55; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 55 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 55; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 54;
		elif (_stack_54 >= 1 and _stack_pointer >= 54 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_54 -= 1; _stack_pointer -= 54; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 54; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 54 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 54; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 53;
		elif (_stack_53 >= 1 and _stack_pointer >= 53 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_53 -= 1; _stack_pointer -= 53; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 53; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 53 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 53; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 52;
		elif (_stack_52 >= 1 and _stack_pointer >= 52 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_52 -= 1; _stack_pointer -= 52; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 52; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 52 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 52; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 51;
		elif (_stack_51 >= 1 and _stack_pointer >= 51 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_51 -= 1; _stack_pointer -= 51; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 51; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 51 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 51; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 50;
		elif (instruction_state >= 1 and _stack_pointer >= 50 and current_instruction >= 38 and _stack_50 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 50; current_instruction -= 38; _stack_50 -= 1;
			next_instruction_state += 1; _next_stack_pointer += 50; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 50 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 50; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 49;
		elif (_stack_49 >= 1 and _stack_pointer >= 49 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_49 -= 1; _stack_pointer -= 49; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 49; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 49 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 49; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 48;
		elif (instruction_state >= 1 and _stack_pointer >= 48 and current_instruction >= 38 and _stack_48 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 48; current_instruction -= 38; _stack_48 -= 1;
			next_instruction_state += 1; _next_stack_pointer += 48; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 48 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 48; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 47;
		elif (_stack_47 >= 1 and _stack_pointer >= 47 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_47 -= 1; _stack_pointer -= 47; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 47; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 47 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 47; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 46;
		elif (_stack_46 >= 1 and _stack_pointer >= 46 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_46 -= 1; _stack_pointer -= 46; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 46; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 46 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 46; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 45;
		elif (_stack_45 >= 1 and _stack_pointer >= 45 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_45 -= 1; _stack_pointer -= 45; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 45; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 45 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 45; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 44;
		elif (_stack_44 >= 1 and _stack_pointer >= 44 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_44 -= 1; _stack_pointer -= 44; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 44; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 44 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 44; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 43;
		elif (_stack_43 >= 1 and _stack_pointer >= 43 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_43 -= 1; _stack_pointer -= 43; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 43; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 43 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 43; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 42;
		elif (_stack_42 >= 1 and _stack_pointer >= 42 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_42 -= 1; _stack_pointer -= 42; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 42; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 42 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 42; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 41;
		elif (_stack_41 >= 1 and _stack_pointer >= 41 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_41 -= 1; _stack_pointer -= 41; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 41; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 41 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 41; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 40;
		elif (_stack_40 >= 1 and _stack_pointer >= 40 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_40 -= 1; _stack_pointer -= 40; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 40; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 40 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 40; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 39;
		elif (instruction_state >= 1 and _stack_pointer >= 39 and current_instruction >= 38 and _stack_39 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 39; current_instruction -= 38; _stack_39 -= 1;
			next_instruction_state += 1; _next_stack_pointer += 39; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 39 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 39; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 38;
		elif (_stack_38 >= 1 and _stack_pointer >= 38 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_38 -= 1; _stack_pointer -= 38; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 38; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 38 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 38; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 37;
		elif (_stack_37 >= 1 and _stack_pointer >= 37 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_37 -= 1; _stack_pointer -= 37; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 37; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 37 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 37; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 36;
		elif (_stack_36 >= 1 and _stack_pointer >= 36 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_36 -= 1; _stack_pointer -= 36; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 36; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 36 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 36; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 35;
		elif (instruction_state >= 1 and _stack_pointer >= 35 and current_instruction >= 38 and _stack_35 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 35; current_instruction -= 38; _stack_35 -= 1;
			next_instruction_state += 1; _next_stack_pointer += 35; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 35 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 35; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 34;
		elif (instruction_state >= 1 and _stack_pointer >= 34 and current_instruction >= 38 and _stack_34 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 34; current_instruction -= 38; _stack_34 -= 1;
			next_instruction_state += 1; _next_stack_pointer += 34; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 34 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 34; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 33;
		elif (_stack_33 >= 1 and _stack_pointer >= 33 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_33 -= 1; _stack_pointer -= 33; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 33; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 33 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 33; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 32;
		elif (_stack_32 >= 1 and _stack_pointer >= 32 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_32 -= 1; _stack_pointer -= 32; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 32; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 32 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 32; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 31;
		elif (instruction_state >= 1 and _stack_pointer >= 31 and current_instruction >= 38 and _stack_31 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 31; current_instruction -= 38; _stack_31 -= 1;
			next_instruction_state += 1; _next_stack_pointer += 31; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 31 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 31; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 30;
		elif (_stack_30 >= 1 and _stack_pointer >= 30 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_30 -= 1; _stack_pointer -= 30; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 30; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 30 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 30; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 29;
		elif (_stack_29 >= 1 and _stack_pointer >= 29 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_29 -= 1; _stack_pointer -= 29; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 29; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 29 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 29; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 28;
		elif (_stack_28 >= 1 and _stack_pointer >= 28 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_28 -= 1; _stack_pointer -= 28; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 28; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 28 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 28; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 27;
		elif (_stack_27 >= 1 and _stack_pointer >= 27 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_27 -= 1; _stack_pointer -= 27; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 27; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 27 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 27; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 26;
		elif (_stack_26 >= 1 and _stack_pointer >= 26 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_26 -= 1; _stack_pointer -= 26; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 26; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 26 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 26; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 25;
		elif (_stack_25 >= 1 and _stack_pointer >= 25 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_25 -= 1; _stack_pointer -= 25; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 25; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 25 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 25; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 24;
		elif (_stack_24 >= 1 and _stack_pointer >= 24 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_24 -= 1; _stack_pointer -= 24; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 24; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 24 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 24; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 23;
		elif (_stack_23 >= 1 and _stack_pointer >= 23 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_23 -= 1; _stack_pointer -= 23; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 23; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 23 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 23; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 22;
		elif (_stack_22 >= 1 and _stack_pointer >= 22 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_22 -= 1; _stack_pointer -= 22; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 22; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 22 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 22; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 21;
		elif (_stack_21 >= 1 and _stack_pointer >= 21 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_21 -= 1; _stack_pointer -= 21; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 21; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 21 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 21; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 20;
		elif (_stack_20 >= 1 and _stack_pointer >= 20 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_20 -= 1; _stack_pointer -= 20; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 20; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 20 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 20; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 19;
		elif (_stack_19 >= 1 and _stack_pointer >= 19 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_19 -= 1; _stack_pointer -= 19; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 19; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 19 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 19; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 18;
		elif (_stack_18 >= 1 and _stack_pointer >= 18 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_18 -= 1; _stack_pointer -= 18; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 18; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 18 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 18; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 17;
		elif (_stack_17 >= 1 and _stack_pointer >= 17 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_17 -= 1; _stack_pointer -= 17; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 17; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 17 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 17; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 16;
		elif (instruction_state >= 1 and _stack_pointer >= 16 and current_instruction >= 38 and _stack_16 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 16; current_instruction -= 38; _stack_16 -= 1;
			next_instruction_state += 1; _next_stack_pointer += 16; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 16 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 16; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 15;
		elif (_stack_15 >= 1 and _stack_pointer >= 15 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_15 -= 1; _stack_pointer -= 15; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 15; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 15 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 15; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 14;
		elif (_stack_14 >= 1 and _stack_pointer >= 14 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_14 -= 1; _stack_pointer -= 14; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 14; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 14 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 14; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 13;
		elif (instruction_state >= 1 and _stack_pointer >= 13 and current_instruction >= 38 and _stack_13 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 13; current_instruction -= 38; _stack_13 -= 1;
			next_instruction_state += 1; _next_stack_pointer += 13; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 13 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 13; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 12;
		elif (_stack_12 >= 1 and _stack_pointer >= 12 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_12 -= 1; _stack_pointer -= 12; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 12; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 12 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 12; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 11;
		elif (_stack_11 >= 1 and _stack_pointer >= 11 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_11 -= 1; _stack_pointer -= 11; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 11; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 11 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 11; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 10;
		elif (_stack_10 >= 1 and _stack_pointer >= 10 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_10 -= 1; _stack_pointer -= 10; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 10; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 10 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 10; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 9;
		elif (instruction_state >= 1 and _stack_pointer >= 9 and current_instruction >= 38 and _stack_9 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 9; current_instruction -= 38; _stack_9 -= 1;
			next_instruction_state += 1; _next_stack_pointer += 9; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 9 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 9; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 8;
		elif (_stack_8 >= 1 and _stack_pointer >= 8 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_8 -= 1; _stack_pointer -= 8; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 8; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 8 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 8; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 7;
		elif (_stack_7 >= 1 and _stack_pointer >= 7 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_7 -= 1; _stack_pointer -= 7; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 7; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 7 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 7; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 6;
		elif (_stack_6 >= 1 and _stack_pointer >= 6 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_6 -= 1; _stack_pointer -= 6; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 6; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 6 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 6; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 5;
		elif (instruction_state >= 1 and _stack_pointer >= 5 and current_instruction >= 38 and _stack_5 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 5; current_instruction -= 38; _stack_5 -= 1;
			next_instruction_state += 1; _next_stack_pointer += 5; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 5 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 5; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 4;
		elif (_stack_4 >= 1 and _stack_pointer >= 4 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_4 -= 1; _stack_pointer -= 4; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 4; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 4 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 4; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 3;
		elif (_stack_3 >= 1 and _stack_pointer >= 3 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_3 -= 1; _stack_pointer -= 3; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 3; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 3 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 3; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 2;
		elif (_stack_2 >= 1 and _stack_pointer >= 2 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_2 -= 1; _stack_pointer -= 2; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 2; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 2 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 2; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 1;
		elif (_stack_1 >= 1 and _stack_pointer >= 1 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_1 -= 1; _stack_pointer -= 1; current_instruction -= 38; instruction_state -= 1;
			next_instruction_state += 1; _next_stack_pointer += 1; arg_one += 1; next_instruction += 38;
		elif (_stack_pointer >= 1 and current_instruction >= 38 and instruction_state >= 1 ):
			_stack_pointer -= 1; current_instruction -= 38; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 0;
		elif (current_instruction >= 38 and instruction_state >= 1 ):
			current_instruction -= 38; instruction_state -= 1;
			ERROR_STACK_UNDERFLOW += 1; next_instruction += 32;
		elif (current_instruction >= 38 and arg_one >= 1 ):
			current_instruction -= 38; arg_one -= 1;
			next_instruction += 38;
		elif (current_instruction >= 38 ):
			current_instruction -= 38;
			next_instruction_state += 1; next_instruction += 38;
		elif (arg_one >= 1 and current_instruction >= 37 and instruction_state >= 2 ):
			arg_one -= 1; current_instruction -= 37; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 37;
		elif (current_instruction >= 37 and instruction_state >= 2 ):
			current_instruction -= 37; instruction_state -= 2;
			next_instruction += 0;
		elif (arg_two >= 1 and current_instruction >= 37 and instruction_state >= 1 ):
			arg_two -= 1; current_instruction -= 37; instruction_state -= 1;
			next_instruction_state += 1; next_instruction += 37;
		elif (current_instruction >= 37 and instruction_state >= 1 ):
			current_instruction -= 37; instruction_state -= 1;
			arg_one += 1; next_instruction += 0;
		elif (arg_two >= 1 and current_instruction >= 37 and arg_one >= 1 ):
			arg_two -= 1; current_instruction -= 37; arg_one -= 1;
			next_instruction += 37;
		elif (current_instruction >= 37 and arg_two >= 1 ):
			current_instruction -= 37; arg_two -= 1;
			next_instruction_state += 1; next_instruction += 37;
		elif (current_instruction >= 37 and arg_one >= 1 ):
			current_instruction -= 37; arg_one -= 1;
			next_instruction_state += 2; next_instruction += 37;
		elif (current_instruction >= 37 ):
			current_instruction -= 37;
			next_instruction_state += 1; next_instruction += 37;
		elif (current_instruction >= 36 and arg_two >= 1 ):
			current_instruction -= 36; arg_two -= 1;
			next_instruction += 36;
		elif (current_instruction >= 36 ):
			current_instruction -= 36;
			next_instruction += 0;
		elif (arg_two >= 1 and current_instruction >= 35 and instruction_state >= 1 ):
			arg_two -= 1; current_instruction -= 35; instruction_state -= 1;
			next_instruction_state += 1; next_instruction += 35;
		elif (current_instruction >= 35 and instruction_state >= 1 ):
			current_instruction -= 35; instruction_state -= 1;
			arg_one += 1; next_instruction += 0;
		elif (arg_two >= 1 and current_instruction >= 35 and arg_one >= 1 ):
			arg_two -= 1; current_instruction -= 35; arg_one -= 1;
			next_instruction += 35;
		elif (current_instruction >= 35 and arg_two >= 1 ):
			current_instruction -= 35; arg_two -= 1;
			next_instruction_state += 1; next_instruction += 35;
		elif (current_instruction >= 35 and arg_one >= 1 ):
			current_instruction -= 35; arg_one -= 1;
			next_instruction += 35;
		elif (current_instruction >= 35 ):
			current_instruction -= 35;
			next_instruction += 0;
		elif (arg_one >= 1 and var_pointer >= 64 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 64; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 64; _stack_64 += 1;
		elif (var_pointer >= 64 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 64; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 64; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 63 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 63; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 63; _stack_63 += 1;
		elif (var_pointer >= 63 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 63; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 63; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 62 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 62; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_62 += 1; _next_var_pointer += 62; next_instruction += 34;
		elif (var_pointer >= 62 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 62; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 62; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 61 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 61; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_61 += 1; _next_var_pointer += 61; next_instruction += 34;
		elif (var_pointer >= 61 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 61; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 61; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 60 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 60; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_60 += 1; _next_var_pointer += 60;
		elif (var_pointer >= 60 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 60; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 60; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 59 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 59; current_instruction -= 34; instruction_state -= 2;
			_stack_59 += 1; next_instruction += 34; _next_var_pointer += 59; next_instruction_state += 2;
		elif (var_pointer >= 59 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 59; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 59; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 58 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 58; current_instruction -= 34; instruction_state -= 2;
			_stack_58 += 1; next_instruction += 34; _next_var_pointer += 58; next_instruction_state += 2;
		elif (var_pointer >= 58 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 58; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 58; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 57 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 57; current_instruction -= 34; instruction_state -= 2;
			_stack_57 += 1; next_instruction += 34; _next_var_pointer += 57; next_instruction_state += 2;
		elif (var_pointer >= 57 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 57; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 57; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 56 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 56; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_56 += 1; _next_var_pointer += 56;
		elif (var_pointer >= 56 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 56; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 56; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 55 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 55; current_instruction -= 34; instruction_state -= 2;
			_stack_55 += 1; next_instruction += 34; _next_var_pointer += 55; next_instruction_state += 2;
		elif (var_pointer >= 55 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 55; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 55; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 54 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 54; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_54 += 1; _next_var_pointer += 54;
		elif (var_pointer >= 54 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 54; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 54; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 53 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 53; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_53 += 1; _next_var_pointer += 53;
		elif (var_pointer >= 53 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 53; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 53; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 52 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 52; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_52 += 1; _next_var_pointer += 52; next_instruction += 34;
		elif (var_pointer >= 52 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 52; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 52; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 51 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 51; current_instruction -= 34; instruction_state -= 2;
			_stack_51 += 1; next_instruction += 34; _next_var_pointer += 51; next_instruction_state += 2;
		elif (var_pointer >= 51 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 51; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 51; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 50 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 50; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 50; _stack_50 += 1;
		elif (var_pointer >= 50 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 50; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 50; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 49 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 49; current_instruction -= 34; instruction_state -= 2;
			_stack_49 += 1; next_instruction += 34; _next_var_pointer += 49; next_instruction_state += 2;
		elif (var_pointer >= 49 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 49; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 49; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 48 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 48; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 48; _stack_48 += 1;
		elif (var_pointer >= 48 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 48; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 48; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 47 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 47; current_instruction -= 34; instruction_state -= 2;
			_stack_47 += 1; next_instruction += 34; _next_var_pointer += 47; next_instruction_state += 2;
		elif (var_pointer >= 47 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 47; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 47; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 46 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 46; current_instruction -= 34; instruction_state -= 2;
			_stack_46 += 1; next_instruction += 34; _next_var_pointer += 46; next_instruction_state += 2;
		elif (var_pointer >= 46 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 46; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 46; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 45 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 45; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_45 += 1; _next_var_pointer += 45; next_instruction += 34;
		elif (var_pointer >= 45 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 45; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 45; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 44 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 44; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_44 += 1; _next_var_pointer += 44;
		elif (var_pointer >= 44 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 44; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 44; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 43 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 43; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_43 += 1; _next_var_pointer += 43;
		elif (var_pointer >= 43 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 43; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 43; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 42 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 42; current_instruction -= 34; instruction_state -= 2;
			_stack_42 += 1; next_instruction += 34; _next_var_pointer += 42; next_instruction_state += 2;
		elif (var_pointer >= 42 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 42; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 42; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 41 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 41; current_instruction -= 34; instruction_state -= 2;
			_stack_41 += 1; next_instruction += 34; _next_var_pointer += 41; next_instruction_state += 2;
		elif (var_pointer >= 41 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 41; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 41; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 40 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 40; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_40 += 1; _next_var_pointer += 40;
		elif (var_pointer >= 40 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 40; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 40; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 39 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 39; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 39; _stack_39 += 1;
		elif (var_pointer >= 39 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 39; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 39; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 38 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 38; current_instruction -= 34; instruction_state -= 2;
			_stack_38 += 1; next_instruction += 34; _next_var_pointer += 38; next_instruction_state += 2;
		elif (var_pointer >= 38 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 38; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 38; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 37 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 37; current_instruction -= 34; instruction_state -= 2;
			_stack_37 += 1; next_instruction += 34; _next_var_pointer += 37; next_instruction_state += 2;
		elif (var_pointer >= 37 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 37; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 37; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 36 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 36; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_36 += 1; _next_var_pointer += 36;
		elif (var_pointer >= 36 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 36; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 36; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 35 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 35; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 35; _stack_35 += 1;
		elif (var_pointer >= 35 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 35; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 35; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 34 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 34; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 34; _stack_34 += 1;
		elif (var_pointer >= 34 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 34; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 34; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 33 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 33; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_33 += 1; _next_var_pointer += 33;
		elif (var_pointer >= 33 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 33; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 33; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 32 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 32; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_32 += 1; _next_var_pointer += 32;
		elif (var_pointer >= 32 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 32; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 32; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 31 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 31; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 31; _stack_31 += 1;
		elif (var_pointer >= 31 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 31; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 31; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 30 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 30; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_30 += 1; _next_var_pointer += 30; next_instruction += 34;
		elif (var_pointer >= 30 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 30; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 30; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 29 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 29; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_29 += 1; _next_var_pointer += 29;
		elif (var_pointer >= 29 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 29; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 29; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 28 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 28; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_28 += 1; _next_var_pointer += 28; next_instruction += 34;
		elif (var_pointer >= 28 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 28; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 28; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 27 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 27; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_27 += 1; _next_var_pointer += 27;
		elif (var_pointer >= 27 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 27; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 27; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 26 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 26; current_instruction -= 34; instruction_state -= 2;
			_stack_26 += 1; next_instruction += 34; _next_var_pointer += 26; next_instruction_state += 2;
		elif (var_pointer >= 26 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 26; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 26; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 25 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 25; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_25 += 1; _next_var_pointer += 25;
		elif (var_pointer >= 25 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 25; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 25; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 24 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 24; current_instruction -= 34; instruction_state -= 2;
			_stack_24 += 1; next_instruction += 34; _next_var_pointer += 24; next_instruction_state += 2;
		elif (var_pointer >= 24 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 24; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 24; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 23 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 23; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_23 += 1; _next_var_pointer += 23; next_instruction += 34;
		elif (var_pointer >= 23 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 23; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 23; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 22 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 22; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_22 += 1; _next_var_pointer += 22; next_instruction += 34;
		elif (var_pointer >= 22 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 22; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 22; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 21 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 21; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_21 += 1; _next_var_pointer += 21;
		elif (var_pointer >= 21 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 21; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 21; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 20 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 20; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_20 += 1; _next_var_pointer += 20;
		elif (var_pointer >= 20 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 20; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 20; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 19 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 19; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_19 += 1; _next_var_pointer += 19; next_instruction += 34;
		elif (var_pointer >= 19 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 19; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 19; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 18 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 18; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_18 += 1; _next_var_pointer += 18; next_instruction += 34;
		elif (var_pointer >= 18 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 18; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 18; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 17 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 17; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_17 += 1; _next_var_pointer += 17; next_instruction += 34;
		elif (var_pointer >= 17 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 17; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 17; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 16 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 16; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 16; _stack_16 += 1;
		elif (var_pointer >= 16 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 16; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 16; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 15 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 15; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_15 += 1; _next_var_pointer += 15; next_instruction += 34;
		elif (var_pointer >= 15 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 15; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 15; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 14 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 14; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_14 += 1; _next_var_pointer += 14;
		elif (var_pointer >= 14 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 14; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 14; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 13 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 13; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 13; _stack_13 += 1;
		elif (var_pointer >= 13 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 13; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 13; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 12 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 12; current_instruction -= 34; instruction_state -= 2;
			_stack_12 += 1; next_instruction += 34; _next_var_pointer += 12; next_instruction_state += 2;
		elif (var_pointer >= 12 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 12; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 12; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 11 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 11; current_instruction -= 34; instruction_state -= 2;
			_stack_11 += 1; next_instruction += 34; _next_var_pointer += 11; next_instruction_state += 2;
		elif (var_pointer >= 11 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 11; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 11; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 10 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 10; current_instruction -= 34; instruction_state -= 2;
			_stack_10 += 1; next_instruction += 34; _next_var_pointer += 10; next_instruction_state += 2;
		elif (var_pointer >= 10 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 10; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 10; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 9 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 9; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 9; _stack_9 += 1;
		elif (var_pointer >= 9 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 9; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 9; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 8 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 8; current_instruction -= 34; instruction_state -= 2;
			_stack_8 += 1; next_instruction += 34; _next_var_pointer += 8; next_instruction_state += 2;
		elif (var_pointer >= 8 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 8; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 8; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 7 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 7; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_7 += 1; _next_var_pointer += 7; next_instruction += 34;
		elif (var_pointer >= 7 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 7; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 7; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 6 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 6; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_6 += 1; _next_var_pointer += 6; next_instruction += 34;
		elif (var_pointer >= 6 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 6; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 6; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 5 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 5; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 5; _stack_5 += 1;
		elif (var_pointer >= 5 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 5; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 5; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 4 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 4; current_instruction -= 34; instruction_state -= 2;
			_stack_4 += 1; next_instruction += 34; _next_var_pointer += 4; next_instruction_state += 2;
		elif (var_pointer >= 4 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 4; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 4; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 3 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 3; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_3 += 1; _next_var_pointer += 3; next_instruction += 34;
		elif (var_pointer >= 3 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 3; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 3; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 2 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 2; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; _stack_2 += 1; _next_var_pointer += 2; next_instruction += 34;
		elif (var_pointer >= 2 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 2; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 2; next_instruction += 11;
		elif (arg_one >= 1 and var_pointer >= 1 and current_instruction >= 34 and instruction_state >= 2 ):
			arg_one -= 1; var_pointer -= 1; current_instruction -= 34; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 34; _stack_1 += 1; _next_var_pointer += 1;
		elif (var_pointer >= 1 and current_instruction >= 34 and instruction_state >= 2 ):
			var_pointer -= 1; current_instruction -= 34; instruction_state -= 2;
			_next_var_pointer += 1; next_instruction += 11;
		elif (var_pointer >= 65 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 65; current_instruction -= 34; instruction_state -= 1;
			ERROR_ABOVE_BOUNDS += 1; next_instruction += 32;
		elif (instruction_state >= 1 and var_pointer >= 64 and current_instruction >= 34 and _stack_64 >= 1 ):
			instruction_state -= 1; var_pointer -= 64; current_instruction -= 34; _stack_64 -= 1;
			_next_var_pointer += 64; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 64 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 64; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 64;
		elif (instruction_state >= 1 and var_pointer >= 63 and current_instruction >= 34 and _stack_63 >= 1 ):
			instruction_state -= 1; var_pointer -= 63; current_instruction -= 34; _stack_63 -= 1;
			_next_var_pointer += 63; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 63 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 63; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 63;
		elif (var_pointer >= 62 and _stack_62 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 62; _stack_62 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 62; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 62 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 62; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 62;
		elif (var_pointer >= 61 and _stack_61 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 61; _stack_61 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 61; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 61 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 61; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 61;
		elif (_stack_60 >= 1 and var_pointer >= 60 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_60 -= 1; var_pointer -= 60; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 60; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 60 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 60; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 60;
		elif (_stack_59 >= 1 and var_pointer >= 59 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_59 -= 1; var_pointer -= 59; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 59; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 59 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 59; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 59;
		elif (_stack_58 >= 1 and var_pointer >= 58 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_58 -= 1; var_pointer -= 58; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 58; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 58 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 58; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 58;
		elif (_stack_57 >= 1 and var_pointer >= 57 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_57 -= 1; var_pointer -= 57; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 57; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 57 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 57; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 57;
		elif (_stack_56 >= 1 and var_pointer >= 56 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_56 -= 1; var_pointer -= 56; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 56; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 56 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 56; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 56;
		elif (_stack_55 >= 1 and var_pointer >= 55 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_55 -= 1; var_pointer -= 55; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 55; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 55 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 55; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 55;
		elif (_stack_54 >= 1 and var_pointer >= 54 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_54 -= 1; var_pointer -= 54; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 54; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 54 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 54; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 54;
		elif (_stack_53 >= 1 and var_pointer >= 53 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_53 -= 1; var_pointer -= 53; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 53; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 53 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 53; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 53;
		elif (var_pointer >= 52 and _stack_52 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 52; _stack_52 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 52; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 52 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 52; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 52;
		elif (_stack_51 >= 1 and var_pointer >= 51 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_51 -= 1; var_pointer -= 51; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 51; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 51 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 51; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 51;
		elif (instruction_state >= 1 and var_pointer >= 50 and current_instruction >= 34 and _stack_50 >= 1 ):
			instruction_state -= 1; var_pointer -= 50; current_instruction -= 34; _stack_50 -= 1;
			_next_var_pointer += 50; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 50 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 50; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 50;
		elif (_stack_49 >= 1 and var_pointer >= 49 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_49 -= 1; var_pointer -= 49; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 49; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 49 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 49; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 49;
		elif (instruction_state >= 1 and var_pointer >= 48 and current_instruction >= 34 and _stack_48 >= 1 ):
			instruction_state -= 1; var_pointer -= 48; current_instruction -= 34; _stack_48 -= 1;
			_next_var_pointer += 48; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 48 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 48; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 48;
		elif (_stack_47 >= 1 and var_pointer >= 47 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_47 -= 1; var_pointer -= 47; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 47; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 47 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 47; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 47;
		elif (_stack_46 >= 1 and var_pointer >= 46 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_46 -= 1; var_pointer -= 46; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 46; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 46 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 46; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 46;
		elif (var_pointer >= 45 and _stack_45 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 45; _stack_45 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 45; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 45 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 45; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 45;
		elif (_stack_44 >= 1 and var_pointer >= 44 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_44 -= 1; var_pointer -= 44; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 44; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 44 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 44; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 44;
		elif (_stack_43 >= 1 and var_pointer >= 43 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_43 -= 1; var_pointer -= 43; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 43; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 43 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 43; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 43;
		elif (_stack_42 >= 1 and var_pointer >= 42 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_42 -= 1; var_pointer -= 42; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 42; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 42 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 42; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 42;
		elif (_stack_41 >= 1 and var_pointer >= 41 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_41 -= 1; var_pointer -= 41; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 41; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 41 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 41; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 41;
		elif (_stack_40 >= 1 and var_pointer >= 40 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_40 -= 1; var_pointer -= 40; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 40; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 40 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 40; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 40;
		elif (instruction_state >= 1 and var_pointer >= 39 and current_instruction >= 34 and _stack_39 >= 1 ):
			instruction_state -= 1; var_pointer -= 39; current_instruction -= 34; _stack_39 -= 1;
			_next_var_pointer += 39; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 39 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 39; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 39;
		elif (_stack_38 >= 1 and var_pointer >= 38 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_38 -= 1; var_pointer -= 38; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 38; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 38 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 38; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 38;
		elif (_stack_37 >= 1 and var_pointer >= 37 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_37 -= 1; var_pointer -= 37; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 37; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 37 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 37; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 37;
		elif (_stack_36 >= 1 and var_pointer >= 36 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_36 -= 1; var_pointer -= 36; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 36; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 36 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 36; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 36;
		elif (instruction_state >= 1 and var_pointer >= 35 and current_instruction >= 34 and _stack_35 >= 1 ):
			instruction_state -= 1; var_pointer -= 35; current_instruction -= 34; _stack_35 -= 1;
			_next_var_pointer += 35; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 35 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 35; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 35;
		elif (instruction_state >= 1 and var_pointer >= 34 and current_instruction >= 34 and _stack_34 >= 1 ):
			instruction_state -= 1; var_pointer -= 34; current_instruction -= 34; _stack_34 -= 1;
			_next_var_pointer += 34; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 34 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 34; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 34;
		elif (_stack_33 >= 1 and var_pointer >= 33 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_33 -= 1; var_pointer -= 33; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 33; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 33 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 33; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 33;
		elif (_stack_32 >= 1 and var_pointer >= 32 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_32 -= 1; var_pointer -= 32; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 32; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 32 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 32; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 32;
		elif (instruction_state >= 1 and var_pointer >= 31 and current_instruction >= 34 and _stack_31 >= 1 ):
			instruction_state -= 1; var_pointer -= 31; current_instruction -= 34; _stack_31 -= 1;
			_next_var_pointer += 31; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 31 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 31; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 31;
		elif (var_pointer >= 30 and _stack_30 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 30; _stack_30 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 30; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 30 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 30; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 30;
		elif (_stack_29 >= 1 and var_pointer >= 29 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_29 -= 1; var_pointer -= 29; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 29; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 29 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 29; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 29;
		elif (var_pointer >= 28 and _stack_28 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 28; _stack_28 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 28; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 28 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 28; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 28;
		elif (_stack_27 >= 1 and var_pointer >= 27 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_27 -= 1; var_pointer -= 27; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 27; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 27 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 27; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 27;
		elif (_stack_26 >= 1 and var_pointer >= 26 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_26 -= 1; var_pointer -= 26; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 26; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 26 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 26; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 26;
		elif (_stack_25 >= 1 and var_pointer >= 25 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_25 -= 1; var_pointer -= 25; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 25; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 25 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 25; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 25;
		elif (_stack_24 >= 1 and var_pointer >= 24 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_24 -= 1; var_pointer -= 24; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 24; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 24 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 24; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 24;
		elif (var_pointer >= 23 and _stack_23 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 23; _stack_23 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 23; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 23 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 23; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 23;
		elif (var_pointer >= 22 and _stack_22 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 22; _stack_22 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 22; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 22 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 22; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 22;
		elif (_stack_21 >= 1 and var_pointer >= 21 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_21 -= 1; var_pointer -= 21; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 21; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 21 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 21; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 21;
		elif (_stack_20 >= 1 and var_pointer >= 20 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_20 -= 1; var_pointer -= 20; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 20; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 20 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 20; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 20;
		elif (var_pointer >= 19 and _stack_19 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 19; _stack_19 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 19; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 19 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 19; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 19;
		elif (var_pointer >= 18 and _stack_18 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 18; _stack_18 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 18; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 18 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 18; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 18;
		elif (var_pointer >= 17 and _stack_17 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 17; _stack_17 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 17; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 17 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 17; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 17;
		elif (instruction_state >= 1 and var_pointer >= 16 and current_instruction >= 34 and _stack_16 >= 1 ):
			instruction_state -= 1; var_pointer -= 16; current_instruction -= 34; _stack_16 -= 1;
			_next_var_pointer += 16; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 16 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 16; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 16;
		elif (var_pointer >= 15 and _stack_15 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 15; _stack_15 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 15; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 15 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 15; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 15;
		elif (_stack_14 >= 1 and var_pointer >= 14 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_14 -= 1; var_pointer -= 14; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 14; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 14 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 14; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 14;
		elif (instruction_state >= 1 and var_pointer >= 13 and current_instruction >= 34 and _stack_13 >= 1 ):
			instruction_state -= 1; var_pointer -= 13; current_instruction -= 34; _stack_13 -= 1;
			_next_var_pointer += 13; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 13 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 13; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 13;
		elif (_stack_12 >= 1 and var_pointer >= 12 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_12 -= 1; var_pointer -= 12; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 12; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 12 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 12; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 12;
		elif (_stack_11 >= 1 and var_pointer >= 11 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_11 -= 1; var_pointer -= 11; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 11; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 11 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 11; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 11;
		elif (_stack_10 >= 1 and var_pointer >= 10 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_10 -= 1; var_pointer -= 10; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 10; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 10 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 10; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 10;
		elif (instruction_state >= 1 and var_pointer >= 9 and current_instruction >= 34 and _stack_9 >= 1 ):
			instruction_state -= 1; var_pointer -= 9; current_instruction -= 34; _stack_9 -= 1;
			_next_var_pointer += 9; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 9 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 9; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 9;
		elif (_stack_8 >= 1 and var_pointer >= 8 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_8 -= 1; var_pointer -= 8; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 8; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 8 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 8; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 8;
		elif (var_pointer >= 7 and _stack_7 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 7; _stack_7 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 7; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 7 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 7; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 7;
		elif (var_pointer >= 6 and _stack_6 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 6; _stack_6 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 6; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 6 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 6; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 6;
		elif (instruction_state >= 1 and var_pointer >= 5 and current_instruction >= 34 and _stack_5 >= 1 ):
			instruction_state -= 1; var_pointer -= 5; current_instruction -= 34; _stack_5 -= 1;
			_next_var_pointer += 5; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 5 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 5; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 5;
		elif (_stack_4 >= 1 and var_pointer >= 4 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_4 -= 1; var_pointer -= 4; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 4; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 4 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 4; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 4;
		elif (var_pointer >= 3 and _stack_3 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 3; _stack_3 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 3; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 3 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 3; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 3;
		elif (var_pointer >= 2 and _stack_2 >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 2; _stack_2 -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 2; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 2 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 2; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 2;
		elif (_stack_1 >= 1 and var_pointer >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			_stack_1 -= 1; var_pointer -= 1; current_instruction -= 34; instruction_state -= 1;
			_next_var_pointer += 1; next_instruction_state += 1; next_instruction += 34; arg_one += 1; _holder_one += 1;
		elif (var_pointer >= 1 and current_instruction >= 34 and instruction_state >= 1 ):
			var_pointer -= 1; current_instruction -= 34; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 34; _next_var_pointer += 1;
		elif (current_instruction >= 34 and instruction_state >= 1 ):
			current_instruction -= 34; instruction_state -= 1;
			next_instruction += 32; ERROR_BELOW_BOUNDS += 1;
		elif (current_instruction >= 34 and arg_one >= 1 ):
			current_instruction -= 34; arg_one -= 1;
			next_instruction += 34;
		elif (current_instruction >= 34 ):
			current_instruction -= 34;
			next_instruction_state += 1; next_instruction += 34;
		elif (instruction_state >= 1 and current_instruction >= 33 and jump_arg >= 1 ):
			instruction_state -= 1; current_instruction -= 33; jump_arg -= 1;
			next_instruction_state += 1; next_instruction += 33;
		elif (current_instruction >= 33 and instruction_state >= 1 ):
			current_instruction -= 33; instruction_state -= 1;
			next_instruction += 0;
		elif (current_instruction >= 33 and _flag_equal >= 1 ):
			current_instruction -= 33; _flag_equal -= 1;
			next_instruction_state += 1; next_instruction += 33;
		elif (current_instruction >= 33 ):
			current_instruction -= 33;
			next_instruction += 26;
		elif (current_instruction >= 32 and var_pointer >= 1 ):
			current_instruction -= 32; var_pointer -= 1;
			next_instruction += 32;
		elif (current_instruction >= 32 and current_pc >= 1 ):
			current_instruction -= 32; current_pc -= 1;
			next_instruction += 32;
		elif (current_instruction >= 32 and next_pc >= 1 ):
			current_instruction -= 32; next_pc -= 1;
			next_instruction += 32;
		elif (current_instruction >= 32 ):
			current_instruction -= 32;
			next_instruction += 0;
		elif (current_instruction >= 31 and _stack_pointer >= 64 ):
			current_instruction -= 31; _stack_pointer -= 64;
			next_instruction += 32; ERROR_STACK_OVERFLOW += 1;
		elif (_stack_pointer >= 63 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 63; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 63; _holder_one += 1; _stack_64 += 1;
		elif (_stack_pointer >= 62 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 62; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 62; _holder_one += 1; _stack_63 += 1;
		elif (_stack_pointer >= 61 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 61; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_62 += 1; _holder_one += 1; _next_stack_pointer += 61;
		elif (_stack_pointer >= 60 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 60; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_61 += 1; _holder_one += 1; _next_stack_pointer += 60;
		elif (_stack_pointer >= 59 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 59; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 59; _stack_60 += 1; _holder_one += 1;
		elif (_stack_pointer >= 58 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 58; current_instruction -= 31; arg_one -= 1;
			_stack_59 += 1; _next_stack_pointer += 58; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 57 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 57; current_instruction -= 31; arg_one -= 1;
			_stack_58 += 1; _next_stack_pointer += 57; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 56 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 56; current_instruction -= 31; arg_one -= 1;
			_stack_57 += 1; _next_stack_pointer += 56; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 55 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 55; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 55; _stack_56 += 1; _holder_one += 1;
		elif (_stack_pointer >= 54 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 54; current_instruction -= 31; arg_one -= 1;
			_stack_55 += 1; _next_stack_pointer += 54; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 53 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 53; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 53; _stack_54 += 1; _holder_one += 1;
		elif (_stack_pointer >= 52 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 52; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 52; _stack_53 += 1; _holder_one += 1;
		elif (_stack_pointer >= 51 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 51; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_52 += 1; _holder_one += 1; _next_stack_pointer += 51;
		elif (_stack_pointer >= 50 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 50; current_instruction -= 31; arg_one -= 1;
			_stack_51 += 1; _next_stack_pointer += 50; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 49 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 49; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 49; _holder_one += 1; _stack_50 += 1;
		elif (_stack_pointer >= 48 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 48; current_instruction -= 31; arg_one -= 1;
			_stack_49 += 1; _next_stack_pointer += 48; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 47 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 47; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 47; _holder_one += 1; _stack_48 += 1;
		elif (_stack_pointer >= 46 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 46; current_instruction -= 31; arg_one -= 1;
			_stack_47 += 1; _next_stack_pointer += 46; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 45 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 45; current_instruction -= 31; arg_one -= 1;
			_stack_46 += 1; _next_stack_pointer += 45; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 44 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 44; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_45 += 1; _holder_one += 1; _next_stack_pointer += 44;
		elif (_stack_pointer >= 43 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 43; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 43; _stack_44 += 1; _holder_one += 1;
		elif (_stack_pointer >= 42 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 42; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 42; _stack_43 += 1; _holder_one += 1;
		elif (_stack_pointer >= 41 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 41; current_instruction -= 31; arg_one -= 1;
			_stack_42 += 1; _next_stack_pointer += 41; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 40 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 40; current_instruction -= 31; arg_one -= 1;
			_stack_41 += 1; _next_stack_pointer += 40; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 39 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 39; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 39; _stack_40 += 1; _holder_one += 1;
		elif (_stack_pointer >= 38 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 38; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 38; _holder_one += 1; _stack_39 += 1;
		elif (_stack_pointer >= 37 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 37; current_instruction -= 31; arg_one -= 1;
			_stack_38 += 1; _next_stack_pointer += 37; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 36 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 36; current_instruction -= 31; arg_one -= 1;
			_stack_37 += 1; _next_stack_pointer += 36; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 35 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 35; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 35; _stack_36 += 1; _holder_one += 1;
		elif (_stack_pointer >= 34 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 34; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 34; _holder_one += 1; _stack_35 += 1;
		elif (_stack_pointer >= 33 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 33; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 33; _holder_one += 1; _stack_34 += 1;
		elif (_stack_pointer >= 32 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 32; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 32; _stack_33 += 1; _holder_one += 1;
		elif (_stack_pointer >= 31 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 31; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 31; _stack_32 += 1; _holder_one += 1;
		elif (_stack_pointer >= 30 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 30; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 30; _holder_one += 1; _stack_31 += 1;
		elif (_stack_pointer >= 29 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 29; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_30 += 1; _holder_one += 1; _next_stack_pointer += 29;
		elif (_stack_pointer >= 28 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 28; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 28; _stack_29 += 1; _holder_one += 1;
		elif (_stack_pointer >= 27 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 27; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_28 += 1; _holder_one += 1; _next_stack_pointer += 27;
		elif (_stack_pointer >= 26 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 26; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 26; _stack_27 += 1; _holder_one += 1;
		elif (_stack_pointer >= 25 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 25; current_instruction -= 31; arg_one -= 1;
			_stack_26 += 1; _next_stack_pointer += 25; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 24 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 24; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 24; _stack_25 += 1; _holder_one += 1;
		elif (_stack_pointer >= 23 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 23; current_instruction -= 31; arg_one -= 1;
			_stack_24 += 1; _next_stack_pointer += 23; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 22 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 22; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_23 += 1; _holder_one += 1; _next_stack_pointer += 22;
		elif (_stack_pointer >= 21 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 21; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_22 += 1; _holder_one += 1; _next_stack_pointer += 21;
		elif (_stack_pointer >= 20 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 20; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 20; _stack_21 += 1; _holder_one += 1;
		elif (_stack_pointer >= 19 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 19; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 19; _stack_20 += 1; _holder_one += 1;
		elif (_stack_pointer >= 18 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 18; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_19 += 1; _holder_one += 1; _next_stack_pointer += 18;
		elif (_stack_pointer >= 17 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 17; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_18 += 1; _holder_one += 1; _next_stack_pointer += 17;
		elif (_stack_pointer >= 16 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 16; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_17 += 1; _holder_one += 1; _next_stack_pointer += 16;
		elif (_stack_pointer >= 15 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 15; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 15; _holder_one += 1; _stack_16 += 1;
		elif (_stack_pointer >= 14 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 14; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_15 += 1; _holder_one += 1; _next_stack_pointer += 14;
		elif (_stack_pointer >= 13 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 13; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 13; _stack_14 += 1; _holder_one += 1;
		elif (_stack_pointer >= 12 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 12; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 12; _holder_one += 1; _stack_13 += 1;
		elif (_stack_pointer >= 11 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 11; current_instruction -= 31; arg_one -= 1;
			_stack_12 += 1; _next_stack_pointer += 11; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 10 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 10; current_instruction -= 31; arg_one -= 1;
			_stack_11 += 1; _next_stack_pointer += 10; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 9 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 9; current_instruction -= 31; arg_one -= 1;
			_stack_10 += 1; _next_stack_pointer += 9; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 8 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 8; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 8; _holder_one += 1; _stack_9 += 1;
		elif (_stack_pointer >= 7 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 7; current_instruction -= 31; arg_one -= 1;
			_stack_8 += 1; _next_stack_pointer += 7; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 6 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 6; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_7 += 1; _holder_one += 1; _next_stack_pointer += 6;
		elif (_stack_pointer >= 5 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 5; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_6 += 1; _holder_one += 1; _next_stack_pointer += 5;
		elif (_stack_pointer >= 4 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 4; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 4; _holder_one += 1; _stack_5 += 1;
		elif (_stack_pointer >= 3 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 3; current_instruction -= 31; arg_one -= 1;
			_stack_4 += 1; _next_stack_pointer += 3; _holder_one += 1; next_instruction += 31;
		elif (_stack_pointer >= 2 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 2; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_3 += 1; _holder_one += 1; _next_stack_pointer += 2;
		elif (_stack_pointer >= 1 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 1; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _stack_2 += 1; _holder_one += 1; _next_stack_pointer += 1;
		elif (_stack_pointer >= 0 and current_instruction >= 31 and arg_one >= 1 ):
			_stack_pointer -= 0; current_instruction -= 31; arg_one -= 1;
			next_instruction += 31; _next_stack_pointer += 0; _stack_1 += 1; _holder_one += 1;
		elif (current_instruction >= 31 ):
			current_instruction -= 31;
			next_instruction += 11; _stack_pointer += 1;
		elif (arg_one >= 1 and current_instruction >= 30 and instruction_state >= 1 ):
			arg_one -= 1; current_instruction -= 30; instruction_state -= 1;
			next_instruction_state += 1; next_instruction += 30;
		elif (current_instruction >= 30 and instruction_state >= 1 ):
			current_instruction -= 30; instruction_state -= 1;
			arg_one += 1; next_instruction += 0;
		elif (arg_two >= 1 and current_instruction >= 30 and arg_one >= 1 ):
			arg_two -= 1; current_instruction -= 30; arg_one -= 1;
			next_instruction += 30;
		elif (current_instruction >= 30 and arg_one >= 1 ):
			current_instruction -= 30; arg_one -= 1;
			next_instruction_state += 1; next_instruction += 30;
		elif (current_instruction >= 30 and arg_two >= 1 ):
			current_instruction -= 30; arg_two -= 1;
			next_instruction += 30;
		elif (current_instruction >= 30 ):
			current_instruction -= 30;
			next_instruction += 0;
		elif (instruction_state >= 2 and current_instruction >= 29 and _holder >= 1 ):
			instruction_state -= 2; current_instruction -= 29; _holder -= 1;
			next_instruction_state += 2; _stack_pointer += 1; next_instruction += 29;
		elif (current_instruction >= 29 and instruction_state >= 2 ):
			current_instruction -= 29; instruction_state -= 2;
			next_instruction += 0;
		elif (_stack_pointer >= 1 and current_instruction >= 29 and instruction_state >= 1 ):
			_stack_pointer -= 1; current_instruction -= 29; instruction_state -= 1;
			stack_frame += 1; next_instruction += 29; next_instruction_state += 1; _holder += 1;
		elif (current_instruction >= 29 and instruction_state >= 1 ):
			current_instruction -= 29; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 29;
		elif (current_instruction >= 29 and stack_frame >= 1 ):
			current_instruction -= 29; stack_frame -= 1;
			next_instruction += 29;
		elif (current_instruction >= 29 ):
			current_instruction -= 29;
			next_instruction_state += 1; next_instruction += 29;
		elif (instruction_state >= 1 and current_instruction >= 28 and _holder >= 1 ):
			instruction_state -= 1; current_instruction -= 28; _holder -= 1;
			stack_frame += 1; next_instruction += 28; next_instruction_state += 1;
		elif (current_instruction >= 28 and instruction_state >= 1 ):
			current_instruction -= 28; instruction_state -= 1;
			next_instruction += 0;
		elif (current_instruction >= 28 and stack_frame >= 1 ):
			current_instruction -= 28; stack_frame -= 1;
			next_instruction += 28; arg_one += 1; _holder += 1;
		elif (current_instruction >= 28 ):
			current_instruction -= 28;
			next_instruction_state += 1; next_instruction += 28;
		elif (instruction_state >= 1 and current_instruction >= 27 and jump_arg >= 1 ):
			instruction_state -= 1; current_instruction -= 27; jump_arg -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 27;
		elif (current_instruction >= 27 and instruction_state >= 1 ):
			current_instruction -= 27; instruction_state -= 1;
			_pc_stack_pointer += 1; next_instruction += 0;
		elif (current_instruction >= 27 and _pc_stack_pointer >= 15 ):
			current_instruction -= 27; _pc_stack_pointer -= 15;
			ERROR_PC_STACK_OVERFLOW += 1; next_instruction += 32;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 14 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 14;
			next_instruction += 27; _pc_stack_15 += 1; _next_pc_stack_pointer += 14;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 13 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 13;
			_pc_stack_14 += 1; next_instruction += 27; _next_pc_stack_pointer += 13;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 12 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 12;
			next_instruction += 27; _pc_stack_13 += 1; _next_pc_stack_pointer += 12;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 11 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 11;
			_pc_stack_12 += 1; next_instruction += 27; _next_pc_stack_pointer += 11;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 10 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 10;
			next_instruction += 27; _next_pc_stack_pointer += 10; _pc_stack_11 += 1;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 9 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 9;
			_pc_stack_10 += 1; next_instruction += 27; _next_pc_stack_pointer += 9;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 8 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 8;
			_pc_stack_9 += 1; next_instruction += 27; _next_pc_stack_pointer += 8;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 7 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 7;
			next_instruction += 27; _pc_stack_8 += 1; _next_pc_stack_pointer += 7;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 6 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 6;
			next_instruction += 27; _next_pc_stack_pointer += 6; _pc_stack_7 += 1;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 5 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 5;
			_pc_stack_6 += 1; next_instruction += 27; _next_pc_stack_pointer += 5;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 4 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 4;
			next_instruction += 27; _next_pc_stack_pointer += 4; _pc_stack_5 += 1;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 3 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 3;
			_pc_stack_4 += 1; next_instruction += 27; _next_pc_stack_pointer += 3;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 2 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 2;
			_pc_stack_3 += 1; next_instruction += 27; _next_pc_stack_pointer += 2;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 1 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 1;
			_pc_stack_2 += 1; next_instruction += 27; _next_pc_stack_pointer += 1;
		elif (next_pc >= 1 and current_instruction >= 27 and _pc_stack_pointer >= 0 ):
			next_pc -= 1; current_instruction -= 27; _pc_stack_pointer -= 0;
			next_instruction += 27; _next_pc_stack_pointer += 0; _pc_stack_1 += 1;
		elif (current_instruction >= 27 ):
			current_instruction -= 27;
			next_instruction_state += 1; next_instruction += 27;
		elif (instruction_state >= 1 and current_instruction >= 26 and jump_arg >= 1 ):
			instruction_state -= 1; current_instruction -= 26; jump_arg -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 26;
		elif (current_instruction >= 26 and instruction_state >= 1 ):
			current_instruction -= 26; instruction_state -= 1;
			next_instruction += 0;
		elif (current_instruction >= 26 and next_pc >= 1 ):
			current_instruction -= 26; next_pc -= 1;
			next_instruction += 26;
		elif (current_instruction >= 26 ):
			current_instruction -= 26;
			next_instruction_state += 1; next_instruction += 26;
		elif (arg_two >= 1 and current_instruction >= 25 and instruction_state >= 1 ):
			arg_two -= 1; current_instruction -= 25; instruction_state -= 1;
			_holder_two += 1; next_instruction += 25; _holder_one += 1; next_instruction_state += 1;
		elif (current_instruction >= 25 and instruction_state >= 1 ):
			current_instruction -= 25; instruction_state -= 1;
			next_instruction += 25;
		elif (current_instruction >= 25 and _holder_two >= 1 ):
			current_instruction -= 25; _holder_two -= 1;
			arg_two += 1; next_instruction += 25;
		elif (current_instruction >= 25 and arg_one >= 1 ):
			current_instruction -= 25; arg_one -= 1;
			next_instruction_state += 1; next_instruction += 25;
		elif (current_instruction >= 25 and arg_two >= 1 ):
			current_instruction -= 25; arg_two -= 1;
			next_instruction += 25;
		elif (current_instruction >= 25 ):
			current_instruction -= 25;
			next_instruction += 11;
		elif (current_instruction >= 24 and arg_one >= 1 ):
			current_instruction -= 24; arg_one -= 1;
			next_instruction += 24;
		elif (current_instruction >= 24 ):
			current_instruction -= 24;
			next_instruction += 0;
		elif (var_pointer_offset >= 1 and current_instruction >= 23 and var_pointer >= 1 ):
			var_pointer_offset -= 1; current_instruction -= 23; var_pointer -= 1;
			next_instruction += 23;
		elif (current_instruction >= 23 and var_pointer_offset >= 1 ):
			current_instruction -= 23; var_pointer_offset -= 1;
			ERROR_VAR_POINTER_UNDERFLOW += 1; next_instruction += 32;
		elif (current_instruction >= 23 ):
			current_instruction -= 23;
			next_instruction += 0;
		elif (current_instruction >= 22 ):
			current_instruction -= 22;
			arg_one += 1; next_instruction += 0;
		elif (arg_one >= 1 and current_instruction >= 21 and instruction_state >= 1 ):
			arg_one -= 1; current_instruction -= 21; instruction_state -= 1;
			next_instruction_state += 1; next_instruction += 21; var_pointer += 1;
		elif (current_instruction >= 21 and instruction_state >= 1 ):
			current_instruction -= 21; instruction_state -= 1;
			next_instruction += 0;
		elif (current_instruction >= 21 and var_pointer >= 1 ):
			current_instruction -= 21; var_pointer -= 1;
			next_instruction += 21;
		elif (current_instruction >= 21 ):
			current_instruction -= 21;
			next_instruction_state += 1; next_instruction += 21;
		elif (arg_two >= 1 and current_instruction >= 20 and instruction_state >= 4 ):
			arg_two -= 1; current_instruction -= 20; instruction_state -= 4;
			next_instruction_state += 4; next_instruction += 20;
		elif (_holder_two >= 1 and current_instruction >= 20 and instruction_state >= 4 ):
			_holder_two -= 1; current_instruction -= 20; instruction_state -= 4;
			next_instruction_state += 4; next_instruction += 20;
		elif (current_instruction >= 20 and instruction_state >= 4 ):
			current_instruction -= 20; instruction_state -= 4;
			next_instruction += 11;
		elif (_holder_two >= 1 and current_instruction >= 20 and instruction_state >= 3 ):
			_holder_two -= 1; current_instruction -= 20; instruction_state -= 3;
			arg_two += 1; next_instruction += 20; next_instruction_state += 3;
		elif (current_instruction >= 20 and instruction_state >= 3 ):
			current_instruction -= 20; instruction_state -= 3;
			next_instruction_state += 2; next_instruction += 20;
		elif (arg_two >= 1 and arg_one >= 1 and current_instruction >= 20 and instruction_state >= 2 ):
			arg_two -= 1; arg_one -= 1; current_instruction -= 20; instruction_state -= 2;
			_holder_two += 1; next_instruction += 20; next_instruction_state += 2;
		elif (arg_two >= 1 and current_instruction >= 20 and instruction_state >= 2 ):
			arg_two -= 1; current_instruction -= 20; instruction_state -= 2;
			next_instruction_state += 4; next_instruction += 20;
		elif (current_instruction >= 20 and instruction_state >= 2 ):
			current_instruction -= 20; instruction_state -= 2;
			next_instruction_state += 3; next_instruction += 20; _holder_one += 1;
		elif (current_instruction >= 20 and instruction_state >= 1 ):
			current_instruction -= 20; instruction_state -= 1;
			arg_two += 1; next_instruction += 20; next_instruction_state += 2;
		elif (current_instruction >= 20 and arg_two >= 1 ):
			current_instruction -= 20; arg_two -= 1;
			next_instruction_state += 1; next_instruction += 20;
		elif (current_instruction >= 20 ):
			current_instruction -= 20;
			ERROR_DIVIDE_BY_ZERO += 1; next_instruction += 32;
		elif (instruction_state >= 1 and current_instruction >= 19 and jump_arg >= 1 ):
			instruction_state -= 1; current_instruction -= 19; jump_arg -= 1;
			next_instruction_state += 1; next_instruction += 19;
		elif (current_instruction >= 19 and instruction_state >= 1 ):
			current_instruction -= 19; instruction_state -= 1;
			next_instruction += 0;
		elif (current_instruction >= 19 and _flag_equal >= 1 ):
			current_instruction -= 19; _flag_equal -= 1;
			next_instruction += 26;
		elif (current_instruction >= 19 ):
			current_instruction -= 19;
			next_instruction_state += 1; next_instruction += 19;
		elif (instruction_state >= 2 and current_instruction >= 18 and _holder >= 1 ):
			instruction_state -= 2; current_instruction -= 18; _holder -= 1;
			stack_frame += 1; next_instruction += 18; next_instruction_state += 2;
		elif (current_instruction >= 18 and instruction_state >= 2 ):
			current_instruction -= 18; instruction_state -= 2;
			next_instruction += 0;
		elif (stack_frame >= 1 and current_instruction >= 18 and instruction_state >= 1 ):
			stack_frame -= 1; current_instruction -= 18; instruction_state -= 1;
			next_instruction_state += 1; next_instruction += 18; var_pointer += 1; _holder += 1;
		elif (current_instruction >= 18 and instruction_state >= 1 ):
			current_instruction -= 18; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 18;
		elif (current_instruction >= 18 and var_pointer >= 1 ):
			current_instruction -= 18; var_pointer -= 1;
			next_instruction += 18;
		elif (current_instruction >= 18 ):
			current_instruction -= 18;
			next_instruction_state += 1; next_instruction += 18;
		elif (arg_one >= 1 and var_pointer >= 64 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 64; current_instruction -= 17; instruction_state -= 1;
			_stack_64 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 64;
		elif (arg_one >= 1 and var_pointer >= 63 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 63; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 63; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _stack_63 += 1;
		elif (arg_one >= 1 and var_pointer >= 62 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 62; current_instruction -= 17; instruction_state -= 1;
			next_instruction += 17; next_instruction_state += 1; _stack_62 += 1; _holder_one += 1; _next_var_pointer += 62;
		elif (arg_one >= 1 and var_pointer >= 61 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 61; current_instruction -= 17; instruction_state -= 1;
			next_instruction += 17; next_instruction_state += 1; _stack_61 += 1; _holder_one += 1; _next_var_pointer += 61;
		elif (arg_one >= 1 and var_pointer >= 60 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 60; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 60; next_instruction_state += 1; next_instruction += 17; _stack_60 += 1; _holder_one += 1;
		elif (arg_one >= 1 and var_pointer >= 59 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 59; current_instruction -= 17; instruction_state -= 1;
			next_instruction_state += 1; _stack_59 += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 59;
		elif (arg_one >= 1 and var_pointer >= 58 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 58; current_instruction -= 17; instruction_state -= 1;
			_stack_58 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 58;
		elif (arg_one >= 1 and var_pointer >= 57 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 57; current_instruction -= 17; instruction_state -= 1;
			next_instruction_state += 1; _stack_57 += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 57;
		elif (arg_one >= 1 and var_pointer >= 56 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 56; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 56; next_instruction_state += 1; next_instruction += 17; _stack_56 += 1; _holder_one += 1;
		elif (arg_one >= 1 and var_pointer >= 55 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 55; current_instruction -= 17; instruction_state -= 1;
			_stack_55 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 55;
		elif (arg_one >= 1 and var_pointer >= 54 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 54; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 54; next_instruction_state += 1; next_instruction += 17; _stack_54 += 1; _holder_one += 1;
		elif (arg_one >= 1 and var_pointer >= 53 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 53; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 53; next_instruction_state += 1; next_instruction += 17; _stack_53 += 1; _holder_one += 1;
		elif (arg_one >= 1 and var_pointer >= 52 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 52; current_instruction -= 17; instruction_state -= 1;
			next_instruction += 17; next_instruction_state += 1; _stack_52 += 1; _holder_one += 1; _next_var_pointer += 52;
		elif (arg_one >= 1 and var_pointer >= 51 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 51; current_instruction -= 17; instruction_state -= 1;
			next_instruction_state += 1; _stack_51 += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 51;
		elif (arg_one >= 1 and var_pointer >= 50 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 50; current_instruction -= 17; instruction_state -= 1;
			_stack_50 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 50;
		elif (arg_one >= 1 and var_pointer >= 49 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 49; current_instruction -= 17; instruction_state -= 1;
			next_instruction_state += 1; _stack_49 += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 49;
		elif (arg_one >= 1 and var_pointer >= 48 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 48; current_instruction -= 17; instruction_state -= 1;
			_stack_48 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 48;
		elif (arg_one >= 1 and var_pointer >= 47 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 47; current_instruction -= 17; instruction_state -= 1;
			next_instruction_state += 1; _stack_47 += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 47;
		elif (arg_one >= 1 and var_pointer >= 46 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 46; current_instruction -= 17; instruction_state -= 1;
			_stack_46 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 46;
		elif (arg_one >= 1 and var_pointer >= 45 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 45; current_instruction -= 17; instruction_state -= 1;
			next_instruction += 17; next_instruction_state += 1; _stack_45 += 1; _holder_one += 1; _next_var_pointer += 45;
		elif (arg_one >= 1 and var_pointer >= 44 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 44; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 44; next_instruction_state += 1; next_instruction += 17; _stack_44 += 1; _holder_one += 1;
		elif (arg_one >= 1 and var_pointer >= 43 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 43; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 43; next_instruction_state += 1; next_instruction += 17; _stack_43 += 1; _holder_one += 1;
		elif (arg_one >= 1 and var_pointer >= 42 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 42; current_instruction -= 17; instruction_state -= 1;
			_stack_42 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 42;
		elif (arg_one >= 1 and var_pointer >= 41 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 41; current_instruction -= 17; instruction_state -= 1;
			next_instruction_state += 1; _stack_41 += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 41;
		elif (arg_one >= 1 and var_pointer >= 40 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 40; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 40; next_instruction_state += 1; next_instruction += 17; _stack_40 += 1; _holder_one += 1;
		elif (arg_one >= 1 and var_pointer >= 39 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 39; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 39; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _stack_39 += 1;
		elif (arg_one >= 1 and var_pointer >= 38 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 38; current_instruction -= 17; instruction_state -= 1;
			next_instruction_state += 1; _stack_38 += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 38;
		elif (arg_one >= 1 and var_pointer >= 37 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 37; current_instruction -= 17; instruction_state -= 1;
			_stack_37 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 37;
		elif (arg_one >= 1 and var_pointer >= 36 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 36; current_instruction -= 17; instruction_state -= 1;
			_stack_36 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 36;
		elif (arg_one >= 1 and var_pointer >= 35 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 35; current_instruction -= 17; instruction_state -= 1;
			_stack_35 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 35;
		elif (arg_one >= 1 and var_pointer >= 34 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 34; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 34; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _stack_34 += 1;
		elif (arg_one >= 1 and var_pointer >= 33 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 33; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 33; next_instruction_state += 1; next_instruction += 17; _stack_33 += 1; _holder_one += 1;
		elif (arg_one >= 1 and var_pointer >= 32 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 32; current_instruction -= 17; instruction_state -= 1;
			_stack_32 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 32;
		elif (arg_one >= 1 and var_pointer >= 31 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 31; current_instruction -= 17; instruction_state -= 1;
			_stack_31 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 31;
		elif (arg_one >= 1 and var_pointer >= 30 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 30; current_instruction -= 17; instruction_state -= 1;
			next_instruction += 17; next_instruction_state += 1; _stack_30 += 1; _holder_one += 1; _next_var_pointer += 30;
		elif (arg_one >= 1 and var_pointer >= 29 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 29; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 29; next_instruction_state += 1; next_instruction += 17; _stack_29 += 1; _holder_one += 1;
		elif (arg_one >= 1 and var_pointer >= 28 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 28; current_instruction -= 17; instruction_state -= 1;
			_stack_28 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 28;
		elif (arg_one >= 1 and var_pointer >= 27 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 27; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 27; next_instruction_state += 1; next_instruction += 17; _stack_27 += 1; _holder_one += 1;
		elif (arg_one >= 1 and var_pointer >= 26 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 26; current_instruction -= 17; instruction_state -= 1;
			_stack_26 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 26;
		elif (arg_one >= 1 and var_pointer >= 25 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 25; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 25; next_instruction_state += 1; next_instruction += 17; _stack_25 += 1; _holder_one += 1;
		elif (arg_one >= 1 and var_pointer >= 24 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 24; current_instruction -= 17; instruction_state -= 1;
			next_instruction_state += 1; _stack_24 += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 24;
		elif (arg_one >= 1 and var_pointer >= 23 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 23; current_instruction -= 17; instruction_state -= 1;
			_stack_23 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 23;
		elif (arg_one >= 1 and var_pointer >= 22 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 22; current_instruction -= 17; instruction_state -= 1;
			_stack_22 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 22;
		elif (arg_one >= 1 and var_pointer >= 21 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 21; current_instruction -= 17; instruction_state -= 1;
			_stack_21 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 21;
		elif (arg_one >= 1 and var_pointer >= 20 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 20; current_instruction -= 17; instruction_state -= 1;
			_stack_20 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 20;
		elif (arg_one >= 1 and var_pointer >= 19 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 19; current_instruction -= 17; instruction_state -= 1;
			next_instruction += 17; next_instruction_state += 1; _stack_19 += 1; _holder_one += 1; _next_var_pointer += 19;
		elif (arg_one >= 1 and var_pointer >= 18 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 18; current_instruction -= 17; instruction_state -= 1;
			next_instruction += 17; next_instruction_state += 1; _stack_18 += 1; _holder_one += 1; _next_var_pointer += 18;
		elif (arg_one >= 1 and var_pointer >= 17 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 17; current_instruction -= 17; instruction_state -= 1;
			next_instruction += 17; next_instruction_state += 1; _stack_17 += 1; _holder_one += 1; _next_var_pointer += 17;
		elif (arg_one >= 1 and var_pointer >= 16 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 16; current_instruction -= 17; instruction_state -= 1;
			_stack_16 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 16;
		elif (arg_one >= 1 and var_pointer >= 15 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 15; current_instruction -= 17; instruction_state -= 1;
			_stack_15 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 15;
		elif (arg_one >= 1 and var_pointer >= 14 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 14; current_instruction -= 17; instruction_state -= 1;
			_stack_14 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 14;
		elif (arg_one >= 1 and var_pointer >= 13 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 13; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 13; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _stack_13 += 1;
		elif (arg_one >= 1 and var_pointer >= 12 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 12; current_instruction -= 17; instruction_state -= 1;
			_stack_12 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 12;
		elif (arg_one >= 1 and var_pointer >= 11 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 11; current_instruction -= 17; instruction_state -= 1;
			next_instruction_state += 1; _stack_11 += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 11;
		elif (arg_one >= 1 and var_pointer >= 10 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 10; current_instruction -= 17; instruction_state -= 1;
			_stack_10 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 10;
		elif (arg_one >= 1 and var_pointer >= 9 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 9; current_instruction -= 17; instruction_state -= 1;
			_stack_9 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 9;
		elif (arg_one >= 1 and var_pointer >= 8 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 8; current_instruction -= 17; instruction_state -= 1;
			next_instruction_state += 1; _stack_8 += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 8;
		elif (arg_one >= 1 and var_pointer >= 7 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 7; current_instruction -= 17; instruction_state -= 1;
			_stack_7 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 7;
		elif (arg_one >= 1 and var_pointer >= 6 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 6; current_instruction -= 17; instruction_state -= 1;
			_stack_6 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 6;
		elif (arg_one >= 1 and var_pointer >= 5 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 5; current_instruction -= 17; instruction_state -= 1;
			_next_var_pointer += 5; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _stack_5 += 1;
		elif (arg_one >= 1 and var_pointer >= 4 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 4; current_instruction -= 17; instruction_state -= 1;
			_stack_4 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 4;
		elif (arg_one >= 1 and var_pointer >= 3 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 3; current_instruction -= 17; instruction_state -= 1;
			_stack_3 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 3;
		elif (arg_one >= 1 and var_pointer >= 2 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 2; current_instruction -= 17; instruction_state -= 1;
			_stack_2 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 2;
		elif (arg_one >= 1 and var_pointer >= 1 and current_instruction >= 17 and instruction_state >= 1 ):
			arg_one -= 1; var_pointer -= 1; current_instruction -= 17; instruction_state -= 1;
			_stack_1 += 1; next_instruction_state += 1; next_instruction += 17; _holder_one += 1; _next_var_pointer += 1;
		elif (current_instruction >= 17 and instruction_state >= 1 ):
			current_instruction -= 17; instruction_state -= 1;
			next_instruction += 11;
		elif (current_instruction >= 17 and var_pointer >= 65 ):
			current_instruction -= 17; var_pointer -= 65;
			ERROR_ABOVE_BOUNDS += 1; next_instruction += 32;
		elif (var_pointer >= 64 and current_instruction >= 17 and _stack_64 >= 1 ):
			var_pointer -= 64; current_instruction -= 17; _stack_64 -= 1;
			_next_var_pointer += 64; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 64 ):
			current_instruction -= 17; var_pointer -= 64;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 64;
		elif (var_pointer >= 63 and current_instruction >= 17 and _stack_63 >= 1 ):
			var_pointer -= 63; current_instruction -= 17; _stack_63 -= 1;
			_next_var_pointer += 63; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 63 ):
			current_instruction -= 17; var_pointer -= 63;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 63;
		elif (_stack_62 >= 1 and current_instruction >= 17 and var_pointer >= 62 ):
			_stack_62 -= 1; current_instruction -= 17; var_pointer -= 62;
			_next_var_pointer += 62; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 62 ):
			current_instruction -= 17; var_pointer -= 62;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 62;
		elif (_stack_61 >= 1 and current_instruction >= 17 and var_pointer >= 61 ):
			_stack_61 -= 1; current_instruction -= 17; var_pointer -= 61;
			_next_var_pointer += 61; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 61 ):
			current_instruction -= 17; var_pointer -= 61;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 61;
		elif (_stack_60 >= 1 and current_instruction >= 17 and var_pointer >= 60 ):
			_stack_60 -= 1; current_instruction -= 17; var_pointer -= 60;
			_next_var_pointer += 60; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 60 ):
			current_instruction -= 17; var_pointer -= 60;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 60;
		elif (_stack_59 >= 1 and current_instruction >= 17 and var_pointer >= 59 ):
			_stack_59 -= 1; current_instruction -= 17; var_pointer -= 59;
			_next_var_pointer += 59; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 59 ):
			current_instruction -= 17; var_pointer -= 59;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 59;
		elif (_stack_58 >= 1 and current_instruction >= 17 and var_pointer >= 58 ):
			_stack_58 -= 1; current_instruction -= 17; var_pointer -= 58;
			_next_var_pointer += 58; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 58 ):
			current_instruction -= 17; var_pointer -= 58;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 58;
		elif (_stack_57 >= 1 and current_instruction >= 17 and var_pointer >= 57 ):
			_stack_57 -= 1; current_instruction -= 17; var_pointer -= 57;
			_next_var_pointer += 57; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 57 ):
			current_instruction -= 17; var_pointer -= 57;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 57;
		elif (_stack_56 >= 1 and current_instruction >= 17 and var_pointer >= 56 ):
			_stack_56 -= 1; current_instruction -= 17; var_pointer -= 56;
			_next_var_pointer += 56; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 56 ):
			current_instruction -= 17; var_pointer -= 56;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 56;
		elif (_stack_55 >= 1 and current_instruction >= 17 and var_pointer >= 55 ):
			_stack_55 -= 1; current_instruction -= 17; var_pointer -= 55;
			_next_var_pointer += 55; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 55 ):
			current_instruction -= 17; var_pointer -= 55;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 55;
		elif (_stack_54 >= 1 and current_instruction >= 17 and var_pointer >= 54 ):
			_stack_54 -= 1; current_instruction -= 17; var_pointer -= 54;
			_next_var_pointer += 54; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 54 ):
			current_instruction -= 17; var_pointer -= 54;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 54;
		elif (_stack_53 >= 1 and current_instruction >= 17 and var_pointer >= 53 ):
			_stack_53 -= 1; current_instruction -= 17; var_pointer -= 53;
			_next_var_pointer += 53; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 53 ):
			current_instruction -= 17; var_pointer -= 53;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 53;
		elif (_stack_52 >= 1 and current_instruction >= 17 and var_pointer >= 52 ):
			_stack_52 -= 1; current_instruction -= 17; var_pointer -= 52;
			_next_var_pointer += 52; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 52 ):
			current_instruction -= 17; var_pointer -= 52;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 52;
		elif (_stack_51 >= 1 and current_instruction >= 17 and var_pointer >= 51 ):
			_stack_51 -= 1; current_instruction -= 17; var_pointer -= 51;
			_next_var_pointer += 51; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 51 ):
			current_instruction -= 17; var_pointer -= 51;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 51;
		elif (var_pointer >= 50 and current_instruction >= 17 and _stack_50 >= 1 ):
			var_pointer -= 50; current_instruction -= 17; _stack_50 -= 1;
			_next_var_pointer += 50; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 50 ):
			current_instruction -= 17; var_pointer -= 50;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 50;
		elif (_stack_49 >= 1 and current_instruction >= 17 and var_pointer >= 49 ):
			_stack_49 -= 1; current_instruction -= 17; var_pointer -= 49;
			_next_var_pointer += 49; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 49 ):
			current_instruction -= 17; var_pointer -= 49;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 49;
		elif (var_pointer >= 48 and current_instruction >= 17 and _stack_48 >= 1 ):
			var_pointer -= 48; current_instruction -= 17; _stack_48 -= 1;
			_next_var_pointer += 48; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 48 ):
			current_instruction -= 17; var_pointer -= 48;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 48;
		elif (_stack_47 >= 1 and current_instruction >= 17 and var_pointer >= 47 ):
			_stack_47 -= 1; current_instruction -= 17; var_pointer -= 47;
			_next_var_pointer += 47; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 47 ):
			current_instruction -= 17; var_pointer -= 47;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 47;
		elif (_stack_46 >= 1 and current_instruction >= 17 and var_pointer >= 46 ):
			_stack_46 -= 1; current_instruction -= 17; var_pointer -= 46;
			_next_var_pointer += 46; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 46 ):
			current_instruction -= 17; var_pointer -= 46;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 46;
		elif (_stack_45 >= 1 and current_instruction >= 17 and var_pointer >= 45 ):
			_stack_45 -= 1; current_instruction -= 17; var_pointer -= 45;
			_next_var_pointer += 45; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 45 ):
			current_instruction -= 17; var_pointer -= 45;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 45;
		elif (_stack_44 >= 1 and current_instruction >= 17 and var_pointer >= 44 ):
			_stack_44 -= 1; current_instruction -= 17; var_pointer -= 44;
			_next_var_pointer += 44; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 44 ):
			current_instruction -= 17; var_pointer -= 44;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 44;
		elif (_stack_43 >= 1 and current_instruction >= 17 and var_pointer >= 43 ):
			_stack_43 -= 1; current_instruction -= 17; var_pointer -= 43;
			_next_var_pointer += 43; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 43 ):
			current_instruction -= 17; var_pointer -= 43;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 43;
		elif (_stack_42 >= 1 and current_instruction >= 17 and var_pointer >= 42 ):
			_stack_42 -= 1; current_instruction -= 17; var_pointer -= 42;
			_next_var_pointer += 42; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 42 ):
			current_instruction -= 17; var_pointer -= 42;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 42;
		elif (_stack_41 >= 1 and current_instruction >= 17 and var_pointer >= 41 ):
			_stack_41 -= 1; current_instruction -= 17; var_pointer -= 41;
			_next_var_pointer += 41; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 41 ):
			current_instruction -= 17; var_pointer -= 41;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 41;
		elif (_stack_40 >= 1 and current_instruction >= 17 and var_pointer >= 40 ):
			_stack_40 -= 1; current_instruction -= 17; var_pointer -= 40;
			_next_var_pointer += 40; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 40 ):
			current_instruction -= 17; var_pointer -= 40;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 40;
		elif (var_pointer >= 39 and current_instruction >= 17 and _stack_39 >= 1 ):
			var_pointer -= 39; current_instruction -= 17; _stack_39 -= 1;
			_next_var_pointer += 39; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 39 ):
			current_instruction -= 17; var_pointer -= 39;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 39;
		elif (_stack_38 >= 1 and current_instruction >= 17 and var_pointer >= 38 ):
			_stack_38 -= 1; current_instruction -= 17; var_pointer -= 38;
			_next_var_pointer += 38; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 38 ):
			current_instruction -= 17; var_pointer -= 38;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 38;
		elif (_stack_37 >= 1 and current_instruction >= 17 and var_pointer >= 37 ):
			_stack_37 -= 1; current_instruction -= 17; var_pointer -= 37;
			_next_var_pointer += 37; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 37 ):
			current_instruction -= 17; var_pointer -= 37;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 37;
		elif (_stack_36 >= 1 and current_instruction >= 17 and var_pointer >= 36 ):
			_stack_36 -= 1; current_instruction -= 17; var_pointer -= 36;
			_next_var_pointer += 36; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 36 ):
			current_instruction -= 17; var_pointer -= 36;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 36;
		elif (var_pointer >= 35 and current_instruction >= 17 and _stack_35 >= 1 ):
			var_pointer -= 35; current_instruction -= 17; _stack_35 -= 1;
			_next_var_pointer += 35; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 35 ):
			current_instruction -= 17; var_pointer -= 35;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 35;
		elif (var_pointer >= 34 and current_instruction >= 17 and _stack_34 >= 1 ):
			var_pointer -= 34; current_instruction -= 17; _stack_34 -= 1;
			_next_var_pointer += 34; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 34 ):
			current_instruction -= 17; var_pointer -= 34;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 34;
		elif (_stack_33 >= 1 and current_instruction >= 17 and var_pointer >= 33 ):
			_stack_33 -= 1; current_instruction -= 17; var_pointer -= 33;
			_next_var_pointer += 33; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 33 ):
			current_instruction -= 17; var_pointer -= 33;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 33;
		elif (_stack_32 >= 1 and current_instruction >= 17 and var_pointer >= 32 ):
			_stack_32 -= 1; current_instruction -= 17; var_pointer -= 32;
			_next_var_pointer += 32; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 32 ):
			current_instruction -= 17; var_pointer -= 32;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 32;
		elif (var_pointer >= 31 and current_instruction >= 17 and _stack_31 >= 1 ):
			var_pointer -= 31; current_instruction -= 17; _stack_31 -= 1;
			_next_var_pointer += 31; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 31 ):
			current_instruction -= 17; var_pointer -= 31;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 31;
		elif (_stack_30 >= 1 and current_instruction >= 17 and var_pointer >= 30 ):
			_stack_30 -= 1; current_instruction -= 17; var_pointer -= 30;
			_next_var_pointer += 30; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 30 ):
			current_instruction -= 17; var_pointer -= 30;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 30;
		elif (_stack_29 >= 1 and current_instruction >= 17 and var_pointer >= 29 ):
			_stack_29 -= 1; current_instruction -= 17; var_pointer -= 29;
			_next_var_pointer += 29; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 29 ):
			current_instruction -= 17; var_pointer -= 29;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 29;
		elif (_stack_28 >= 1 and current_instruction >= 17 and var_pointer >= 28 ):
			_stack_28 -= 1; current_instruction -= 17; var_pointer -= 28;
			_next_var_pointer += 28; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 28 ):
			current_instruction -= 17; var_pointer -= 28;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 28;
		elif (_stack_27 >= 1 and current_instruction >= 17 and var_pointer >= 27 ):
			_stack_27 -= 1; current_instruction -= 17; var_pointer -= 27;
			_next_var_pointer += 27; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 27 ):
			current_instruction -= 17; var_pointer -= 27;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 27;
		elif (_stack_26 >= 1 and current_instruction >= 17 and var_pointer >= 26 ):
			_stack_26 -= 1; current_instruction -= 17; var_pointer -= 26;
			_next_var_pointer += 26; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 26 ):
			current_instruction -= 17; var_pointer -= 26;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 26;
		elif (_stack_25 >= 1 and current_instruction >= 17 and var_pointer >= 25 ):
			_stack_25 -= 1; current_instruction -= 17; var_pointer -= 25;
			_next_var_pointer += 25; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 25 ):
			current_instruction -= 17; var_pointer -= 25;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 25;
		elif (_stack_24 >= 1 and current_instruction >= 17 and var_pointer >= 24 ):
			_stack_24 -= 1; current_instruction -= 17; var_pointer -= 24;
			_next_var_pointer += 24; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 24 ):
			current_instruction -= 17; var_pointer -= 24;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 24;
		elif (_stack_23 >= 1 and current_instruction >= 17 and var_pointer >= 23 ):
			_stack_23 -= 1; current_instruction -= 17; var_pointer -= 23;
			_next_var_pointer += 23; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 23 ):
			current_instruction -= 17; var_pointer -= 23;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 23;
		elif (_stack_22 >= 1 and current_instruction >= 17 and var_pointer >= 22 ):
			_stack_22 -= 1; current_instruction -= 17; var_pointer -= 22;
			_next_var_pointer += 22; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 22 ):
			current_instruction -= 17; var_pointer -= 22;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 22;
		elif (_stack_21 >= 1 and current_instruction >= 17 and var_pointer >= 21 ):
			_stack_21 -= 1; current_instruction -= 17; var_pointer -= 21;
			_next_var_pointer += 21; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 21 ):
			current_instruction -= 17; var_pointer -= 21;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 21;
		elif (_stack_20 >= 1 and current_instruction >= 17 and var_pointer >= 20 ):
			_stack_20 -= 1; current_instruction -= 17; var_pointer -= 20;
			_next_var_pointer += 20; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 20 ):
			current_instruction -= 17; var_pointer -= 20;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 20;
		elif (_stack_19 >= 1 and current_instruction >= 17 and var_pointer >= 19 ):
			_stack_19 -= 1; current_instruction -= 17; var_pointer -= 19;
			_next_var_pointer += 19; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 19 ):
			current_instruction -= 17; var_pointer -= 19;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 19;
		elif (_stack_18 >= 1 and current_instruction >= 17 and var_pointer >= 18 ):
			_stack_18 -= 1; current_instruction -= 17; var_pointer -= 18;
			_next_var_pointer += 18; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 18 ):
			current_instruction -= 17; var_pointer -= 18;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 18;
		elif (_stack_17 >= 1 and current_instruction >= 17 and var_pointer >= 17 ):
			_stack_17 -= 1; current_instruction -= 17; var_pointer -= 17;
			_next_var_pointer += 17; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 17 ):
			current_instruction -= 17; var_pointer -= 17;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 17;
		elif (var_pointer >= 16 and current_instruction >= 17 and _stack_16 >= 1 ):
			var_pointer -= 16; current_instruction -= 17; _stack_16 -= 1;
			_next_var_pointer += 16; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 16 ):
			current_instruction -= 17; var_pointer -= 16;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 16;
		elif (_stack_15 >= 1 and current_instruction >= 17 and var_pointer >= 15 ):
			_stack_15 -= 1; current_instruction -= 17; var_pointer -= 15;
			_next_var_pointer += 15; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 15 ):
			current_instruction -= 17; var_pointer -= 15;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 15;
		elif (_stack_14 >= 1 and current_instruction >= 17 and var_pointer >= 14 ):
			_stack_14 -= 1; current_instruction -= 17; var_pointer -= 14;
			_next_var_pointer += 14; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 14 ):
			current_instruction -= 17; var_pointer -= 14;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 14;
		elif (var_pointer >= 13 and current_instruction >= 17 and _stack_13 >= 1 ):
			var_pointer -= 13; current_instruction -= 17; _stack_13 -= 1;
			_next_var_pointer += 13; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 13 ):
			current_instruction -= 17; var_pointer -= 13;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 13;
		elif (_stack_12 >= 1 and current_instruction >= 17 and var_pointer >= 12 ):
			_stack_12 -= 1; current_instruction -= 17; var_pointer -= 12;
			_next_var_pointer += 12; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 12 ):
			current_instruction -= 17; var_pointer -= 12;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 12;
		elif (_stack_11 >= 1 and current_instruction >= 17 and var_pointer >= 11 ):
			_stack_11 -= 1; current_instruction -= 17; var_pointer -= 11;
			_next_var_pointer += 11; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 11 ):
			current_instruction -= 17; var_pointer -= 11;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 11;
		elif (_stack_10 >= 1 and current_instruction >= 17 and var_pointer >= 10 ):
			_stack_10 -= 1; current_instruction -= 17; var_pointer -= 10;
			_next_var_pointer += 10; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 10 ):
			current_instruction -= 17; var_pointer -= 10;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 10;
		elif (var_pointer >= 9 and current_instruction >= 17 and _stack_9 >= 1 ):
			var_pointer -= 9; current_instruction -= 17; _stack_9 -= 1;
			_next_var_pointer += 9; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 9 ):
			current_instruction -= 17; var_pointer -= 9;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 9;
		elif (_stack_8 >= 1 and current_instruction >= 17 and var_pointer >= 8 ):
			_stack_8 -= 1; current_instruction -= 17; var_pointer -= 8;
			_next_var_pointer += 8; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 8 ):
			current_instruction -= 17; var_pointer -= 8;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 8;
		elif (_stack_7 >= 1 and current_instruction >= 17 and var_pointer >= 7 ):
			_stack_7 -= 1; current_instruction -= 17; var_pointer -= 7;
			_next_var_pointer += 7; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 7 ):
			current_instruction -= 17; var_pointer -= 7;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 7;
		elif (_stack_6 >= 1 and current_instruction >= 17 and var_pointer >= 6 ):
			_stack_6 -= 1; current_instruction -= 17; var_pointer -= 6;
			_next_var_pointer += 6; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 6 ):
			current_instruction -= 17; var_pointer -= 6;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 6;
		elif (var_pointer >= 5 and current_instruction >= 17 and _stack_5 >= 1 ):
			var_pointer -= 5; current_instruction -= 17; _stack_5 -= 1;
			_next_var_pointer += 5; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 5 ):
			current_instruction -= 17; var_pointer -= 5;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 5;
		elif (_stack_4 >= 1 and current_instruction >= 17 and var_pointer >= 4 ):
			_stack_4 -= 1; current_instruction -= 17; var_pointer -= 4;
			_next_var_pointer += 4; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 4 ):
			current_instruction -= 17; var_pointer -= 4;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 4;
		elif (_stack_3 >= 1 and current_instruction >= 17 and var_pointer >= 3 ):
			_stack_3 -= 1; current_instruction -= 17; var_pointer -= 3;
			_next_var_pointer += 3; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 3 ):
			current_instruction -= 17; var_pointer -= 3;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 3;
		elif (_stack_2 >= 1 and current_instruction >= 17 and var_pointer >= 2 ):
			_stack_2 -= 1; current_instruction -= 17; var_pointer -= 2;
			_next_var_pointer += 2; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 2 ):
			current_instruction -= 17; var_pointer -= 2;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 2;
		elif (_stack_1 >= 1 and current_instruction >= 17 and var_pointer >= 1 ):
			_stack_1 -= 1; current_instruction -= 17; var_pointer -= 1;
			_next_var_pointer += 1; next_instruction += 17;
		elif (current_instruction >= 17 and var_pointer >= 1 ):
			current_instruction -= 17; var_pointer -= 1;
			next_instruction_state += 1; next_instruction += 17; _next_var_pointer += 1;
		elif (current_instruction >= 17 ):
			current_instruction -= 17;
			next_instruction += 32; ERROR_BELOW_BOUNDS += 1;
		elif (current_instruction >= 16 and _stack_pointer >= 64 ):
			current_instruction -= 16; _stack_pointer -= 64;
			next_instruction += 32; ERROR_STACK_OVERFLOW += 1;
		elif (arg_two >= 1 and _stack_pointer >= 63 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 63; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 63; next_instruction += 16; _stack_64 += 1;
		elif (arg_two >= 1 and _stack_pointer >= 62 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 62; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 62; next_instruction += 16; _stack_63 += 1;
		elif (arg_two >= 1 and _stack_pointer >= 61 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 61; current_instruction -= 16;
			_holder_two += 1; _stack_62 += 1; next_instruction += 16; _next_stack_pointer += 61;
		elif (arg_two >= 1 and _stack_pointer >= 60 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 60; current_instruction -= 16;
			_holder_two += 1; _stack_61 += 1; next_instruction += 16; _next_stack_pointer += 60;
		elif (arg_two >= 1 and _stack_pointer >= 59 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 59; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 59; _stack_60 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 58 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 58; current_instruction -= 16;
			_stack_59 += 1; _next_stack_pointer += 58; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 57 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 57; current_instruction -= 16;
			_stack_58 += 1; _next_stack_pointer += 57; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 56 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 56; current_instruction -= 16;
			_stack_57 += 1; _next_stack_pointer += 56; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 55 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 55; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 55; _stack_56 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 54 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 54; current_instruction -= 16;
			_stack_55 += 1; _next_stack_pointer += 54; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 53 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 53; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 53; _stack_54 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 52 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 52; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 52; _stack_53 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 51 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 51; current_instruction -= 16;
			_holder_two += 1; _stack_52 += 1; next_instruction += 16; _next_stack_pointer += 51;
		elif (arg_two >= 1 and _stack_pointer >= 50 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 50; current_instruction -= 16;
			_stack_51 += 1; _next_stack_pointer += 50; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 49 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 49; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 49; next_instruction += 16; _stack_50 += 1;
		elif (arg_two >= 1 and _stack_pointer >= 48 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 48; current_instruction -= 16;
			_stack_49 += 1; _next_stack_pointer += 48; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 47 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 47; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 47; next_instruction += 16; _stack_48 += 1;
		elif (arg_two >= 1 and _stack_pointer >= 46 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 46; current_instruction -= 16;
			_stack_47 += 1; _next_stack_pointer += 46; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 45 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 45; current_instruction -= 16;
			_stack_46 += 1; _next_stack_pointer += 45; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 44 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 44; current_instruction -= 16;
			_holder_two += 1; _stack_45 += 1; next_instruction += 16; _next_stack_pointer += 44;
		elif (arg_two >= 1 and _stack_pointer >= 43 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 43; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 43; _stack_44 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 42 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 42; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 42; _stack_43 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 41 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 41; current_instruction -= 16;
			_stack_42 += 1; _next_stack_pointer += 41; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 40 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 40; current_instruction -= 16;
			_stack_41 += 1; _next_stack_pointer += 40; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 39 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 39; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 39; _stack_40 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 38 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 38; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 38; next_instruction += 16; _stack_39 += 1;
		elif (arg_two >= 1 and _stack_pointer >= 37 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 37; current_instruction -= 16;
			_stack_38 += 1; _next_stack_pointer += 37; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 36 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 36; current_instruction -= 16;
			_stack_37 += 1; _next_stack_pointer += 36; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 35 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 35; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 35; _stack_36 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 34 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 34; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 34; next_instruction += 16; _stack_35 += 1;
		elif (arg_two >= 1 and _stack_pointer >= 33 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 33; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 33; next_instruction += 16; _stack_34 += 1;
		elif (arg_two >= 1 and _stack_pointer >= 32 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 32; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 32; _stack_33 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 31 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 31; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 31; _stack_32 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 30 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 30; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 30; next_instruction += 16; _stack_31 += 1;
		elif (arg_two >= 1 and _stack_pointer >= 29 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 29; current_instruction -= 16;
			_holder_two += 1; _stack_30 += 1; next_instruction += 16; _next_stack_pointer += 29;
		elif (arg_two >= 1 and _stack_pointer >= 28 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 28; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 28; _stack_29 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 27 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 27; current_instruction -= 16;
			_holder_two += 1; _stack_28 += 1; next_instruction += 16; _next_stack_pointer += 27;
		elif (arg_two >= 1 and _stack_pointer >= 26 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 26; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 26; _stack_27 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 25 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 25; current_instruction -= 16;
			_stack_26 += 1; _next_stack_pointer += 25; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 24 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 24; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 24; _stack_25 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 23 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 23; current_instruction -= 16;
			_stack_24 += 1; _next_stack_pointer += 23; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 22 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 22; current_instruction -= 16;
			_holder_two += 1; _stack_23 += 1; next_instruction += 16; _next_stack_pointer += 22;
		elif (arg_two >= 1 and _stack_pointer >= 21 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 21; current_instruction -= 16;
			_holder_two += 1; _stack_22 += 1; next_instruction += 16; _next_stack_pointer += 21;
		elif (arg_two >= 1 and _stack_pointer >= 20 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 20; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 20; _stack_21 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 19 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 19; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 19; _stack_20 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 18 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 18; current_instruction -= 16;
			_holder_two += 1; _stack_19 += 1; next_instruction += 16; _next_stack_pointer += 18;
		elif (arg_two >= 1 and _stack_pointer >= 17 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 17; current_instruction -= 16;
			_holder_two += 1; _stack_18 += 1; next_instruction += 16; _next_stack_pointer += 17;
		elif (arg_two >= 1 and _stack_pointer >= 16 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 16; current_instruction -= 16;
			_holder_two += 1; _stack_17 += 1; next_instruction += 16; _next_stack_pointer += 16;
		elif (arg_two >= 1 and _stack_pointer >= 15 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 15; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 15; next_instruction += 16; _stack_16 += 1;
		elif (arg_two >= 1 and _stack_pointer >= 14 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 14; current_instruction -= 16;
			_holder_two += 1; _stack_15 += 1; next_instruction += 16; _next_stack_pointer += 14;
		elif (arg_two >= 1 and _stack_pointer >= 13 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 13; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 13; _stack_14 += 1; next_instruction += 16;
		elif (arg_two >= 1 and _stack_pointer >= 12 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 12; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 12; next_instruction += 16; _stack_13 += 1;
		elif (arg_two >= 1 and _stack_pointer >= 11 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 11; current_instruction -= 16;
			_stack_12 += 1; _next_stack_pointer += 11; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 10 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 10; current_instruction -= 16;
			_stack_11 += 1; _next_stack_pointer += 10; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 9 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 9; current_instruction -= 16;
			_stack_10 += 1; _next_stack_pointer += 9; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 8 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 8; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 8; next_instruction += 16; _stack_9 += 1;
		elif (arg_two >= 1 and _stack_pointer >= 7 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 7; current_instruction -= 16;
			_stack_8 += 1; _next_stack_pointer += 7; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 6 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 6; current_instruction -= 16;
			_holder_two += 1; _stack_7 += 1; next_instruction += 16; _next_stack_pointer += 6;
		elif (arg_two >= 1 and _stack_pointer >= 5 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 5; current_instruction -= 16;
			_holder_two += 1; _stack_6 += 1; next_instruction += 16; _next_stack_pointer += 5;
		elif (arg_two >= 1 and _stack_pointer >= 4 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 4; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 4; next_instruction += 16; _stack_5 += 1;
		elif (arg_two >= 1 and _stack_pointer >= 3 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 3; current_instruction -= 16;
			_stack_4 += 1; _next_stack_pointer += 3; next_instruction += 16; _holder_two += 1;
		elif (arg_two >= 1 and _stack_pointer >= 2 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 2; current_instruction -= 16;
			_holder_two += 1; _stack_3 += 1; next_instruction += 16; _next_stack_pointer += 2;
		elif (arg_two >= 1 and _stack_pointer >= 1 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 1; current_instruction -= 16;
			_holder_two += 1; _stack_2 += 1; next_instruction += 16; _next_stack_pointer += 1;
		elif (arg_two >= 1 and _stack_pointer >= 0 and current_instruction >= 16 ):
			arg_two -= 1; _stack_pointer -= 0; current_instruction -= 16;
			_holder_two += 1; _next_stack_pointer += 0; _stack_1 += 1; next_instruction += 16;
		elif (current_instruction >= 16 ):
			current_instruction -= 16;
			next_instruction += 11; _stack_pointer += 1;
		elif (instruction_state >= 1 and _stack_pointer >= 64 and current_instruction >= 15 and _stack_64 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 64; current_instruction -= 15; _stack_64 -= 1;
			arg_two += 1; _next_stack_pointer += 64; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 64 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 64; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 63;
		elif (instruction_state >= 1 and _stack_pointer >= 63 and current_instruction >= 15 and _stack_63 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 63; current_instruction -= 15; _stack_63 -= 1;
			arg_two += 1; _next_stack_pointer += 63; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 63 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 63; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 62;
		elif (_stack_62 >= 1 and _stack_pointer >= 62 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_62 -= 1; _stack_pointer -= 62; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 62; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 62 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 62; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 61;
		elif (_stack_61 >= 1 and _stack_pointer >= 61 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_61 -= 1; _stack_pointer -= 61; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 61; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 61 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 61; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 60;
		elif (_stack_60 >= 1 and _stack_pointer >= 60 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_60 -= 1; _stack_pointer -= 60; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 60; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 60 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 60; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 59;
		elif (_stack_59 >= 1 and _stack_pointer >= 59 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_59 -= 1; _stack_pointer -= 59; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 59; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 59 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 59; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 58;
		elif (_stack_58 >= 1 and _stack_pointer >= 58 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_58 -= 1; _stack_pointer -= 58; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 58; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 58 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 58; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 57;
		elif (_stack_57 >= 1 and _stack_pointer >= 57 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_57 -= 1; _stack_pointer -= 57; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 57; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 57 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 57; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 56;
		elif (_stack_56 >= 1 and _stack_pointer >= 56 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_56 -= 1; _stack_pointer -= 56; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 56; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 56 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 56; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 55;
		elif (_stack_55 >= 1 and _stack_pointer >= 55 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_55 -= 1; _stack_pointer -= 55; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 55; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 55 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 55; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 54;
		elif (_stack_54 >= 1 and _stack_pointer >= 54 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_54 -= 1; _stack_pointer -= 54; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 54; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 54 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 54; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 53;
		elif (_stack_53 >= 1 and _stack_pointer >= 53 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_53 -= 1; _stack_pointer -= 53; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 53; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 53 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 53; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 52;
		elif (_stack_52 >= 1 and _stack_pointer >= 52 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_52 -= 1; _stack_pointer -= 52; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 52; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 52 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 52; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 51;
		elif (_stack_51 >= 1 and _stack_pointer >= 51 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_51 -= 1; _stack_pointer -= 51; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 51; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 51 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 51; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 50;
		elif (instruction_state >= 1 and _stack_pointer >= 50 and current_instruction >= 15 and _stack_50 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 50; current_instruction -= 15; _stack_50 -= 1;
			arg_two += 1; _next_stack_pointer += 50; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 50 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 50; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 49;
		elif (_stack_49 >= 1 and _stack_pointer >= 49 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_49 -= 1; _stack_pointer -= 49; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 49; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 49 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 49; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 48;
		elif (instruction_state >= 1 and _stack_pointer >= 48 and current_instruction >= 15 and _stack_48 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 48; current_instruction -= 15; _stack_48 -= 1;
			arg_two += 1; _next_stack_pointer += 48; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 48 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 48; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 47;
		elif (_stack_47 >= 1 and _stack_pointer >= 47 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_47 -= 1; _stack_pointer -= 47; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 47; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 47 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 47; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 46;
		elif (_stack_46 >= 1 and _stack_pointer >= 46 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_46 -= 1; _stack_pointer -= 46; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 46; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 46 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 46; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 45;
		elif (_stack_45 >= 1 and _stack_pointer >= 45 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_45 -= 1; _stack_pointer -= 45; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 45; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 45 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 45; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 44;
		elif (_stack_44 >= 1 and _stack_pointer >= 44 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_44 -= 1; _stack_pointer -= 44; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 44; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 44 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 44; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 43;
		elif (_stack_43 >= 1 and _stack_pointer >= 43 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_43 -= 1; _stack_pointer -= 43; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 43; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 43 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 43; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 42;
		elif (_stack_42 >= 1 and _stack_pointer >= 42 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_42 -= 1; _stack_pointer -= 42; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 42; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 42 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 42; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 41;
		elif (_stack_41 >= 1 and _stack_pointer >= 41 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_41 -= 1; _stack_pointer -= 41; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 41; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 41 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 41; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 40;
		elif (_stack_40 >= 1 and _stack_pointer >= 40 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_40 -= 1; _stack_pointer -= 40; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 40; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 40 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 40; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 39;
		elif (instruction_state >= 1 and _stack_pointer >= 39 and current_instruction >= 15 and _stack_39 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 39; current_instruction -= 15; _stack_39 -= 1;
			arg_two += 1; _next_stack_pointer += 39; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 39 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 39; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 38;
		elif (_stack_38 >= 1 and _stack_pointer >= 38 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_38 -= 1; _stack_pointer -= 38; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 38; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 38 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 38; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 37;
		elif (_stack_37 >= 1 and _stack_pointer >= 37 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_37 -= 1; _stack_pointer -= 37; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 37; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 37 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 37; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 36;
		elif (_stack_36 >= 1 and _stack_pointer >= 36 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_36 -= 1; _stack_pointer -= 36; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 36; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 36 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 36; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 35;
		elif (instruction_state >= 1 and _stack_pointer >= 35 and current_instruction >= 15 and _stack_35 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 35; current_instruction -= 15; _stack_35 -= 1;
			arg_two += 1; _next_stack_pointer += 35; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 35 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 35; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 34;
		elif (instruction_state >= 1 and _stack_pointer >= 34 and current_instruction >= 15 and _stack_34 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 34; current_instruction -= 15; _stack_34 -= 1;
			arg_two += 1; _next_stack_pointer += 34; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 34 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 34; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 33;
		elif (_stack_33 >= 1 and _stack_pointer >= 33 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_33 -= 1; _stack_pointer -= 33; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 33; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 33 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 33; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 32;
		elif (_stack_32 >= 1 and _stack_pointer >= 32 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_32 -= 1; _stack_pointer -= 32; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 32; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 32 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 32; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 31;
		elif (instruction_state >= 1 and _stack_pointer >= 31 and current_instruction >= 15 and _stack_31 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 31; current_instruction -= 15; _stack_31 -= 1;
			arg_two += 1; _next_stack_pointer += 31; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 31 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 31; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 30;
		elif (_stack_30 >= 1 and _stack_pointer >= 30 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_30 -= 1; _stack_pointer -= 30; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 30; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 30 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 30; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 29;
		elif (_stack_29 >= 1 and _stack_pointer >= 29 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_29 -= 1; _stack_pointer -= 29; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 29; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 29 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 29; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 28;
		elif (_stack_28 >= 1 and _stack_pointer >= 28 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_28 -= 1; _stack_pointer -= 28; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 28; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 28 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 28; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 27;
		elif (_stack_27 >= 1 and _stack_pointer >= 27 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_27 -= 1; _stack_pointer -= 27; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 27; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 27 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 27; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 26;
		elif (_stack_26 >= 1 and _stack_pointer >= 26 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_26 -= 1; _stack_pointer -= 26; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 26; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 26 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 26; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 25;
		elif (_stack_25 >= 1 and _stack_pointer >= 25 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_25 -= 1; _stack_pointer -= 25; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 25; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 25 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 25; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 24;
		elif (_stack_24 >= 1 and _stack_pointer >= 24 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_24 -= 1; _stack_pointer -= 24; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 24; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 24 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 24; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 23;
		elif (_stack_23 >= 1 and _stack_pointer >= 23 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_23 -= 1; _stack_pointer -= 23; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 23; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 23 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 23; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 22;
		elif (_stack_22 >= 1 and _stack_pointer >= 22 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_22 -= 1; _stack_pointer -= 22; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 22; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 22 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 22; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 21;
		elif (_stack_21 >= 1 and _stack_pointer >= 21 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_21 -= 1; _stack_pointer -= 21; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 21; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 21 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 21; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 20;
		elif (_stack_20 >= 1 and _stack_pointer >= 20 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_20 -= 1; _stack_pointer -= 20; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 20; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 20 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 20; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 19;
		elif (_stack_19 >= 1 and _stack_pointer >= 19 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_19 -= 1; _stack_pointer -= 19; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 19; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 19 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 19; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 18;
		elif (_stack_18 >= 1 and _stack_pointer >= 18 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_18 -= 1; _stack_pointer -= 18; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 18; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 18 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 18; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 17;
		elif (_stack_17 >= 1 and _stack_pointer >= 17 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_17 -= 1; _stack_pointer -= 17; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 17; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 17 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 17; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 16;
		elif (instruction_state >= 1 and _stack_pointer >= 16 and current_instruction >= 15 and _stack_16 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 16; current_instruction -= 15; _stack_16 -= 1;
			arg_two += 1; _next_stack_pointer += 16; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 16 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 16; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 15;
		elif (_stack_15 >= 1 and _stack_pointer >= 15 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_15 -= 1; _stack_pointer -= 15; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 15; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 15 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 15; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 14;
		elif (_stack_14 >= 1 and _stack_pointer >= 14 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_14 -= 1; _stack_pointer -= 14; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 14; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 14 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 14; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 13;
		elif (instruction_state >= 1 and _stack_pointer >= 13 and current_instruction >= 15 and _stack_13 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 13; current_instruction -= 15; _stack_13 -= 1;
			arg_two += 1; _next_stack_pointer += 13; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 13 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 13; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 12;
		elif (_stack_12 >= 1 and _stack_pointer >= 12 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_12 -= 1; _stack_pointer -= 12; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 12; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 12 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 12; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 11;
		elif (_stack_11 >= 1 and _stack_pointer >= 11 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_11 -= 1; _stack_pointer -= 11; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 11; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 11 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 11; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 10;
		elif (_stack_10 >= 1 and _stack_pointer >= 10 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_10 -= 1; _stack_pointer -= 10; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 10; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 10 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 10; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 9;
		elif (instruction_state >= 1 and _stack_pointer >= 9 and current_instruction >= 15 and _stack_9 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 9; current_instruction -= 15; _stack_9 -= 1;
			arg_two += 1; _next_stack_pointer += 9; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 9 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 9; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 8;
		elif (_stack_8 >= 1 and _stack_pointer >= 8 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_8 -= 1; _stack_pointer -= 8; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 8; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 8 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 8; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 7;
		elif (_stack_7 >= 1 and _stack_pointer >= 7 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_7 -= 1; _stack_pointer -= 7; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 7; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 7 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 7; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 6;
		elif (_stack_6 >= 1 and _stack_pointer >= 6 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_6 -= 1; _stack_pointer -= 6; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 6; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 6 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 6; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 5;
		elif (instruction_state >= 1 and _stack_pointer >= 5 and current_instruction >= 15 and _stack_5 >= 1 ):
			instruction_state -= 1; _stack_pointer -= 5; current_instruction -= 15; _stack_5 -= 1;
			arg_two += 1; _next_stack_pointer += 5; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 5 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 5; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 4;
		elif (_stack_4 >= 1 and _stack_pointer >= 4 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_4 -= 1; _stack_pointer -= 4; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 4; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 4 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 4; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 3;
		elif (_stack_3 >= 1 and _stack_pointer >= 3 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_3 -= 1; _stack_pointer -= 3; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 3; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 3 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 3; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 2;
		elif (_stack_2 >= 1 and _stack_pointer >= 2 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_2 -= 1; _stack_pointer -= 2; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 2; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 2 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 2; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 1;
		elif (_stack_1 >= 1 and _stack_pointer >= 1 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_1 -= 1; _stack_pointer -= 1; current_instruction -= 15; instruction_state -= 1;
			arg_two += 1; _next_stack_pointer += 1; next_instruction += 15; next_instruction_state += 1;
		elif (_stack_pointer >= 1 and current_instruction >= 15 and instruction_state >= 1 ):
			_stack_pointer -= 1; current_instruction -= 15; instruction_state -= 1;
			next_instruction += 0; _next_stack_pointer += 0;
		elif (current_instruction >= 15 and instruction_state >= 1 ):
			current_instruction -= 15; instruction_state -= 1;
			ERROR_STACK_UNDERFLOW += 1; next_instruction += 32;
		elif (current_instruction >= 15 and arg_two >= 1 ):
			current_instruction -= 15; arg_two -= 1;
			next_instruction += 15;
		elif (current_instruction >= 15 ):
			current_instruction -= 15;
			next_instruction_state += 1; next_instruction += 15;
		elif (current_instruction >= 14 and var_pointer >= 1 ):
			current_instruction -= 14; var_pointer -= 1;
			arg_one += 1; next_instruction += 14;
		elif (current_instruction >= 14 ):
			current_instruction -= 14;
			next_instruction += 0;
		elif (current_instruction >= 13 and arg_two >= 1 ):
			current_instruction -= 13; arg_two -= 1;
			arg_one += 1; next_instruction += 13;
		elif (current_instruction >= 13 ):
			current_instruction -= 13;
			next_instruction += 0;
		elif (arg_two >= 1 and current_instruction >= 12 and instruction_state >= 1 ):
			arg_two -= 1; current_instruction -= 12; instruction_state -= 1;
			next_instruction_state += 1; next_instruction += 12;
		elif (arg_one >= 1 and current_instruction >= 12 and instruction_state >= 1 ):
			arg_one -= 1; current_instruction -= 12; instruction_state -= 1;
			next_instruction_state += 1; next_instruction += 12;
		elif (current_instruction >= 12 and instruction_state >= 1 ):
			current_instruction -= 12; instruction_state -= 1;
			next_instruction += 0;
		elif (arg_two >= 1 and current_instruction >= 12 and arg_one >= 1 ):
			arg_two -= 1; current_instruction -= 12; arg_one -= 1;
			next_instruction += 12;
		elif (current_instruction >= 12 and arg_two >= 1 ):
			current_instruction -= 12; arg_two -= 1;
			next_instruction_state += 1; next_instruction += 12;
		elif (current_instruction >= 12 and arg_one >= 1 ):
			current_instruction -= 12; arg_one -= 1;
			next_instruction_state += 1; next_instruction += 12;
		elif (current_instruction >= 12 ):
			current_instruction -= 12;
			arg_one += 1; next_instruction += 0;
		elif (current_instruction >= 11 and _holder_one >= 1 ):
			current_instruction -= 11; _holder_one -= 1;
			arg_one += 1; next_instruction += 11;
		elif (current_instruction >= 11 and _holder_two >= 1 ):
			current_instruction -= 11; _holder_two -= 1;
			arg_two += 1; next_instruction += 11;
		elif (current_instruction >= 11 ):
			current_instruction -= 11;
			next_instruction += 0;
		elif (instruction_state >= 2 and current_instruction >= 10 and jump_arg >= 1 ):
			instruction_state -= 2; current_instruction -= 10; jump_arg -= 1;
			next_instruction_state += 2; next_pc += 1; next_instruction += 10;
		elif (current_instruction >= 10 and instruction_state >= 2 ):
			current_instruction -= 10; instruction_state -= 2;
			next_instruction += 0;
		elif (_pc_stack_15 >= 1 and _pc_stack_pointer >= 15 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_15 -= 1; _pc_stack_pointer -= 15; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 15;
		elif (_pc_stack_pointer >= 15 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 15; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 14;
		elif (_pc_stack_14 >= 1 and _pc_stack_pointer >= 14 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_14 -= 1; _pc_stack_pointer -= 14; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 14;
		elif (_pc_stack_pointer >= 14 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 14; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 13;
		elif (_pc_stack_13 >= 1 and _pc_stack_pointer >= 13 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_13 -= 1; _pc_stack_pointer -= 13; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 13;
		elif (_pc_stack_pointer >= 13 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 13; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 12;
		elif (_pc_stack_pointer >= 12 and _pc_stack_12 >= 1 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 12; _pc_stack_12 -= 1; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 12;
		elif (_pc_stack_pointer >= 12 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 12; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 11;
		elif (instruction_state >= 1 and _pc_stack_pointer >= 11 and current_instruction >= 10 and _pc_stack_11 >= 1 ):
			instruction_state -= 1; _pc_stack_pointer -= 11; current_instruction -= 10; _pc_stack_11 -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 11;
		elif (_pc_stack_pointer >= 11 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 11; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 10;
		elif (_pc_stack_pointer >= 10 and _pc_stack_10 >= 1 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 10; _pc_stack_10 -= 1; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 10;
		elif (_pc_stack_pointer >= 10 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 10; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 9;
		elif (_pc_stack_pointer >= 9 and _pc_stack_9 >= 1 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 9; _pc_stack_9 -= 1; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 9;
		elif (_pc_stack_pointer >= 9 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 9; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 8;
		elif (_pc_stack_8 >= 1 and _pc_stack_pointer >= 8 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_8 -= 1; _pc_stack_pointer -= 8; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 8;
		elif (_pc_stack_pointer >= 8 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 8; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 7;
		elif (instruction_state >= 1 and _pc_stack_pointer >= 7 and current_instruction >= 10 and _pc_stack_7 >= 1 ):
			instruction_state -= 1; _pc_stack_pointer -= 7; current_instruction -= 10; _pc_stack_7 -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 7;
		elif (_pc_stack_pointer >= 7 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 7; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 6;
		elif (_pc_stack_6 >= 1 and _pc_stack_pointer >= 6 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_6 -= 1; _pc_stack_pointer -= 6; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 6;
		elif (_pc_stack_pointer >= 6 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 6; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 5;
		elif (instruction_state >= 1 and _pc_stack_pointer >= 5 and current_instruction >= 10 and _pc_stack_5 >= 1 ):
			instruction_state -= 1; _pc_stack_pointer -= 5; current_instruction -= 10; _pc_stack_5 -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 5;
		elif (_pc_stack_pointer >= 5 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 5; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 4;
		elif (_pc_stack_pointer >= 4 and _pc_stack_4 >= 1 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 4; _pc_stack_4 -= 1; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 4;
		elif (_pc_stack_pointer >= 4 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 4; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 3;
		elif (_pc_stack_pointer >= 3 and _pc_stack_3 >= 1 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 3; _pc_stack_3 -= 1; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 3;
		elif (_pc_stack_pointer >= 3 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 3; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 2;
		elif (_pc_stack_2 >= 1 and _pc_stack_pointer >= 2 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_2 -= 1; _pc_stack_pointer -= 2; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 2;
		elif (_pc_stack_pointer >= 2 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 2; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 1;
		elif (instruction_state >= 1 and _pc_stack_pointer >= 1 and current_instruction >= 10 and _pc_stack_1 >= 1 ):
			instruction_state -= 1; _pc_stack_pointer -= 1; current_instruction -= 10; _pc_stack_1 -= 1;
			next_instruction_state += 1; next_pc += 1; next_instruction += 10; _next_pc_stack_pointer += 1;
		elif (_pc_stack_pointer >= 1 and current_instruction >= 10 and instruction_state >= 1 ):
			_pc_stack_pointer -= 1; current_instruction -= 10; instruction_state -= 1;
			next_instruction_state += 2; next_instruction += 10; _next_pc_stack_pointer += 0;
		elif (current_instruction >= 10 and instruction_state >= 1 ):
			current_instruction -= 10; instruction_state -= 1;
			ERROR_PC_STACK_UNDERFLOW += 1; next_instruction += 32;
		elif (current_instruction >= 10 and next_pc >= 1 ):
			current_instruction -= 10; next_pc -= 1;
			next_instruction += 10;
		elif (current_instruction >= 10 ):
			current_instruction -= 10;
			next_instruction_state += 1; next_instruction += 10;
		elif (current_instruction >= 9 and _flag_equal >= 1 ):
			current_instruction -= 9; _flag_equal -= 1;
			next_instruction += 9;
		elif (arg_two >= 1 and current_instruction >= 9 and arg_one >= 1 ):
			arg_two -= 1; current_instruction -= 9; arg_one -= 1;
			_holder_two += 1; next_instruction += 9; _holder_one += 1;
		elif (current_instruction >= 9 and arg_one >= 1 ):
			current_instruction -= 9; arg_one -= 1;
			_holder_one += 1; next_instruction += 11;
		elif (current_instruction >= 9 and arg_two >= 1 ):
			current_instruction -= 9; arg_two -= 1;
			_holder_two += 1; next_instruction += 11;
		elif (current_instruction >= 9 ):
			current_instruction -= 9;
			next_instruction += 11; _flag_equal += 1;
		elif (arg_two >= 1 and current_instruction >= 8 and instruction_state >= 2 ):
			arg_two -= 1; current_instruction -= 8; instruction_state -= 2;
			next_instruction_state += 2; next_instruction += 8;
		elif (current_instruction >= 8 and instruction_state >= 2 ):
			current_instruction -= 8; instruction_state -= 2;
			next_instruction += 0;
		elif (arg_one >= 1 and current_instruction >= 8 and instruction_state >= 1 ):
			arg_one -= 1; current_instruction -= 8; instruction_state -= 1;
			next_instruction_state += 1; next_instruction += 8;
		elif (current_instruction >= 8 and instruction_state >= 1 ):
			current_instruction -= 8; instruction_state -= 1;
			arg_one += 1; next_instruction += 0;
		elif (arg_two >= 1 and current_instruction >= 8 and arg_one >= 1 ):
			arg_two -= 1; current_instruction -= 8; arg_one -= 1;
			next_instruction += 8;
		elif (current_instruction >= 8 and arg_one >= 1 ):
			current_instruction -= 8; arg_one -= 1;
			next_instruction_state += 1; next_instruction += 8;
		elif (current_instruction >= 8 and arg_two >= 1 ):
			current_instruction -= 8; arg_two -= 1;
			next_instruction_state += 2; next_instruction += 8;
		elif (current_instruction >= 8 ):
			current_instruction -= 8;
			next_instruction_state += 1; next_instruction += 8;
		elif (_holder_two >= 1 and current_instruction >= 7 and instruction_state >= 5 ):
			_holder_two -= 1; current_instruction -= 7; instruction_state -= 5;
			next_instruction_state += 5; next_instruction += 7; _holder_one += 1;
		elif (current_instruction >= 7 and instruction_state >= 5 ):
			current_instruction -= 7; instruction_state -= 5;
			next_instruction += 11;
		elif (arg_two >= 1 and current_instruction >= 7 and instruction_state >= 4 ):
			arg_two -= 1; current_instruction -= 7; instruction_state -= 4;
			next_instruction_state += 4; next_instruction += 7;
		elif (_holder_one >= 1 and current_instruction >= 7 and instruction_state >= 4 ):
			_holder_one -= 1; current_instruction -= 7; instruction_state -= 4;
			next_instruction_state += 4; next_instruction += 7;
		elif (current_instruction >= 7 and instruction_state >= 4 ):
			current_instruction -= 7; instruction_state -= 4;
			next_instruction_state += 5; next_instruction += 7;
		elif (_holder_two >= 1 and current_instruction >= 7 and instruction_state >= 3 ):
			_holder_two -= 1; current_instruction -= 7; instruction_state -= 3;
			arg_two += 1; next_instruction += 7; next_instruction_state += 3;
		elif (current_instruction >= 7 and instruction_state >= 3 ):
			current_instruction -= 7; instruction_state -= 3;
			next_instruction_state += 2; next_instruction += 7;
		elif (arg_two >= 1 and arg_one >= 1 and current_instruction >= 7 and instruction_state >= 2 ):
			arg_two -= 1; arg_one -= 1; current_instruction -= 7; instruction_state -= 2;
			_holder_two += 1; next_instruction += 7; next_instruction_state += 2;
		elif (arg_two >= 1 and current_instruction >= 7 and instruction_state >= 2 ):
			arg_two -= 1; current_instruction -= 7; instruction_state -= 2;
			next_instruction_state += 4; next_instruction += 7;
		elif (current_instruction >= 7 and instruction_state >= 2 ):
			current_instruction -= 7; instruction_state -= 2;
			next_instruction_state += 3; next_instruction += 7; _holder_one += 1;
		elif (current_instruction >= 7 and instruction_state >= 1 ):
			current_instruction -= 7; instruction_state -= 1;
			arg_two += 1; next_instruction += 7; next_instruction_state += 2;
		elif (current_instruction >= 7 and arg_two >= 1 ):
			current_instruction -= 7; arg_two -= 1;
			next_instruction_state += 1; next_instruction += 7;
		elif (current_instruction >= 7 ):
			current_instruction -= 7;
			ERROR_DIVIDE_BY_ZERO += 1; next_instruction += 32;
		elif (arg_one >= 1 and current_instruction >= 6 and instruction_state >= 1 ):
			arg_one -= 1; current_instruction -= 6; instruction_state -= 1;
			stack_frame += 1; next_instruction += 6; next_instruction_state += 1;
		elif (current_instruction >= 6 and instruction_state >= 1 ):
			current_instruction -= 6; instruction_state -= 1;
			next_instruction += 0;
		elif (current_instruction >= 6 and stack_frame >= 1 ):
			current_instruction -= 6; stack_frame -= 1;
			next_instruction += 6;
		elif (current_instruction >= 6 ):
			current_instruction -= 6;
			next_instruction_state += 1; next_instruction += 6;
		elif (current_instruction >= 5 and arg_one >= 1 ):
			current_instruction -= 5; arg_one -= 1;
			next_instruction += 0;
		elif (current_instruction >= 5 ):
			current_instruction -= 5;
			next_instruction += 32; ERROR_DECREMENT_UNDERFLOW += 1;
		elif (current_instruction >= 4 and arg_one >= 1 ):
			current_instruction -= 4; arg_one -= 1;
			_holder_two += 1; next_instruction += 4;
		elif (current_instruction >= 4 and arg_two >= 1 ):
			current_instruction -= 4; arg_two -= 1;
			_holder_one += 1; next_instruction += 4;
		elif (current_instruction >= 4 ):
			current_instruction -= 4;
			next_instruction += 11;
		elif (current_instruction >= 3 and var_pointer_offset >= 1 ):
			current_instruction -= 3; var_pointer_offset -= 1;
			var_pointer += 1; next_instruction += 3;
		elif (current_instruction >= 3 ):
			current_instruction -= 3;
			next_instruction += 0;
		elif (arg_one >= 1 and current_instruction >= 2 and instruction_state >= 1 ):
			arg_one -= 1; current_instruction -= 2; instruction_state -= 1;
			next_instruction_state += 1; next_instruction += 2;
		elif (current_instruction >= 2 and instruction_state >= 1 ):
			current_instruction -= 2; instruction_state -= 1;
			next_instruction += 0;
		elif (current_instruction >= 2 and arg_one >= 1 ):
			current_instruction -= 2; arg_one -= 1;
			next_instruction_state += 1; next_instruction += 2;
		elif (current_instruction >= 2 ):
			current_instruction -= 2;
			arg_one += 1; next_instruction += 0;
		elif (arg_two >= 1 and current_instruction >= 1 and arg_one >= 1 ):
			arg_two -= 1; current_instruction -= 1; arg_one -= 1;
			next_instruction += 1;
		elif (current_instruction >= 1 and arg_two >= 1 ):
			current_instruction -= 1; arg_two -= 1;
			next_instruction += 32; ERROR_SUBTRACT_UNDERFLOW += 1;
		elif (current_instruction >= 1 ):
			current_instruction -= 1;
			next_instruction += 0;
		elif (next_pc >= 1 ):
			next_pc -= 1;
			current_pc += 1;
		elif (current_pc >= 91 ):
			current_pc -= 91;
			next_pc += 90; current_instruction += 27; jump_arg += 89;
		elif (current_pc >= 90 ):
			current_pc -= 90;
			current_instruction += 32; next_pc += 89;
		elif (current_pc >= 89 ):
			current_pc -= 89;
			current_instruction += 24; next_pc += 88;
		elif (current_pc >= 88 ):
			current_pc -= 88;
			current_instruction += 28; next_pc += 87;
		elif (current_pc >= 87 ):
			current_pc -= 87;
			current_instruction += 31; next_pc += 86;
		elif (current_pc >= 86 ):
			current_pc -= 86;
			current_instruction += 29; next_pc += 85;
		elif (current_pc >= 85 ):
			current_pc -= 85;
			current_instruction += 24; next_pc += 84;
		elif (current_pc >= 84 ):
			current_pc -= 84;
			current_instruction += 31; next_pc += 83;
		elif (current_pc >= 83 ):
			current_pc -= 83;
			current_instruction += 31; next_pc += 82;
		elif (current_pc >= 82 ):
			current_pc -= 82;
			current_instruction += 24; next_pc += 81;
		elif (current_pc >= 81 ):
			current_pc -= 81;
			next_pc += 80; current_instruction += 31; arg_one += 0;
		elif (current_pc >= 80 ):
			current_pc -= 80;
			current_instruction += 18; next_pc += 79;
		elif (current_pc >= 79 ):
			current_pc -= 79;
			next_pc += 78; current_instruction += 3; var_pointer_offset += 1;
		elif (current_pc >= 78 ):
			current_pc -= 78;
			current_instruction += 38; next_pc += 77;
		elif (current_pc >= 77 ):
			current_pc -= 77;
			current_instruction += 17; next_pc += 76;
		elif (current_pc >= 76 ):
			current_pc -= 76;
			current_instruction += 24; next_pc += 75;
		elif (current_pc >= 75 ):
			current_pc -= 75;
			next_pc += 74; current_instruction += 31; arg_one += 1;
		elif (current_pc >= 74 ):
			current_pc -= 74;
			current_instruction += 18; next_pc += 73;
		elif (current_pc >= 73 ):
			current_pc -= 73;
			next_pc += 72; current_instruction += 3; var_pointer_offset += 2;
		elif (current_pc >= 72 ):
			current_pc -= 72;
			current_instruction += 38; next_pc += 71;
		elif (current_pc >= 71 ):
			current_pc -= 71;
			current_instruction += 17; next_pc += 70;
		elif (current_pc >= 70 ):
			current_pc -= 70;
			next_pc += 69; current_instruction += 18; arg_one += 1;
		elif (current_pc >= 69 ):
			current_pc -= 69;
			next_pc += 68; current_instruction += 3; var_pointer_offset += 2;
		elif (current_pc >= 68 ):
			current_pc -= 68;
			current_instruction += 34; next_pc += 67;
		elif (current_pc >= 67 ):
			current_pc -= 67;
			current_instruction += 31; next_pc += 66;
		elif (current_pc >= 66 ):
			current_pc -= 66;
			current_instruction += 24; next_pc += 65;
		elif (current_pc >= 65 ):
			current_pc -= 65;
			next_pc += 64; current_instruction += 15; arg_one += 1000;
		elif (current_pc >= 64 ):
			current_pc -= 64;
			current_instruction += 4; next_pc += 63;
		elif (current_pc >= 63 ):
			current_pc -= 63;
			current_instruction += 35; next_pc += 62;
		elif (current_pc >= 62 ):
			current_pc -= 62;
			current_instruction += 36; next_pc += 61;
		elif (current_pc >= 61 ):
			current_pc -= 61;
			current_instruction += 9; next_pc += 60;
		elif (current_pc >= 60 ):
			current_pc -= 60;
			next_pc += 59; current_instruction += 19; jump_arg += 11;
		elif (current_pc >= 59 ):
			current_pc -= 59;
			current_instruction += 18; next_pc += 58;
		elif (current_pc >= 58 ):
			current_pc -= 58;
			next_pc += 57; current_instruction += 3; var_pointer_offset += 2;
		elif (current_pc >= 57 ):
			current_pc -= 57;
			current_instruction += 34; next_pc += 56;
		elif (current_pc >= 56 ):
			current_pc -= 56;
			current_instruction += 31; next_pc += 55;
		elif (current_pc >= 55 ):
			current_pc -= 55;
			current_instruction += 24; next_pc += 54;
		elif (current_pc >= 54 ):
			current_pc -= 54;
			next_pc += 53; current_instruction += 15; arg_one += 5;
		elif (current_pc >= 53 ):
			current_pc -= 53;
			current_instruction += 4; next_pc += 52;
		elif (current_pc >= 52 ):
			current_pc -= 52;
			current_instruction += 7; next_pc += 51;
		elif (current_pc >= 51 ):
			current_pc -= 51;
			current_instruction += 31; next_pc += 50;
		elif (current_pc >= 50 ):
			current_pc -= 50;
			current_instruction += 24; next_pc += 49;
		elif (current_pc >= 49 ):
			current_pc -= 49;
			next_pc += 48; current_instruction += 15; arg_one += 0;
		elif (current_pc >= 48 ):
			current_pc -= 48;
			current_instruction += 4; next_pc += 47;
		elif (current_pc >= 47 ):
			current_pc -= 47;
			current_instruction += 12; next_pc += 46;
		elif (current_pc >= 46 ):
			current_pc -= 46;
			current_instruction += 36; next_pc += 45;
		elif (current_pc >= 45 ):
			current_pc -= 45;
			current_instruction += 9; next_pc += 44;
		elif (current_pc >= 44 ):
			current_pc -= 44;
			next_pc += 43; current_instruction += 33; jump_arg += 30;
		elif (current_pc >= 43 ):
			current_pc -= 43;
			current_instruction += 18; next_pc += 42;
		elif (current_pc >= 42 ):
			current_pc -= 42;
			next_pc += 41; current_instruction += 3; var_pointer_offset += 2;
		elif (current_pc >= 41 ):
			current_pc -= 41;
			current_instruction += 34; next_pc += 40;
		elif (current_pc >= 40 ):
			current_pc -= 40;
			current_instruction += 31; next_pc += 39;
		elif (current_pc >= 39 ):
			current_pc -= 39;
			current_instruction += 24; next_pc += 38;
		elif (current_pc >= 38 ):
			current_pc -= 38;
			next_pc += 37; current_instruction += 15; arg_one += 3;
		elif (current_pc >= 37 ):
			current_pc -= 37;
			current_instruction += 4; next_pc += 36;
		elif (current_pc >= 36 ):
			current_pc -= 36;
			current_instruction += 7; next_pc += 35;
		elif (current_pc >= 35 ):
			current_pc -= 35;
			current_instruction += 31; next_pc += 34;
		elif (current_pc >= 34 ):
			current_pc -= 34;
			current_instruction += 24; next_pc += 33;
		elif (current_pc >= 33 ):
			current_pc -= 33;
			next_pc += 32; current_instruction += 15; arg_one += 0;
		elif (current_pc >= 32 ):
			current_pc -= 32;
			current_instruction += 4; next_pc += 31;
		elif (current_pc >= 31 ):
			current_pc -= 31;
			current_instruction += 12; next_pc += 30;
		elif (current_pc >= 30 ):
			current_pc -= 30;
			current_instruction += 36; next_pc += 29;
		elif (current_pc >= 29 ):
			current_pc -= 29;
			current_instruction += 9; next_pc += 28;
		elif (current_pc >= 28 ):
			current_pc -= 28;
			next_pc += 27; current_instruction += 19; jump_arg += 17;
		elif (current_pc >= 27 ):
			current_pc -= 27;
			current_instruction += 18; next_pc += 26;
		elif (current_pc >= 26 ):
			current_pc -= 26;
			next_pc += 25; current_instruction += 3; var_pointer_offset += 2;
		elif (current_pc >= 25 ):
			current_pc -= 25;
			current_instruction += 34; next_pc += 24;
		elif (current_pc >= 24 ):
			current_pc -= 24;
			current_instruction += 31; next_pc += 23;
		elif (current_pc >= 23 ):
			current_pc -= 23;
			current_instruction += 18; next_pc += 22;
		elif (current_pc >= 22 ):
			current_pc -= 22;
			next_pc += 21; current_instruction += 3; var_pointer_offset += 1;
		elif (current_pc >= 21 ):
			current_pc -= 21;
			current_instruction += 15; next_pc += 20;
		elif (current_pc >= 20 ):
			current_pc -= 20;
			current_instruction += 34; next_pc += 19;
		elif (current_pc >= 19 ):
			current_pc -= 19;
			current_instruction += 13; next_pc += 18;
		elif (current_pc >= 18 ):
			current_pc -= 18;
			current_instruction += 17; next_pc += 17;
		elif (current_pc >= 17 ):
			current_pc -= 17;
			current_instruction += 18; next_pc += 16;
		elif (current_pc >= 16 ):
			current_pc -= 16;
			next_pc += 15; current_instruction += 3; var_pointer_offset += 2;
		elif (current_pc >= 15 ):
			current_pc -= 15;
			current_instruction += 34; next_pc += 14;
		elif (current_pc >= 14 ):
			current_pc -= 14;
			current_instruction += 22; next_pc += 13;
		elif (current_pc >= 13 ):
			current_pc -= 13;
			current_instruction += 17; next_pc += 12;
		elif (current_pc >= 12 ):
			current_pc -= 12;
			next_pc += 11; current_instruction += 26; jump_arg += 70;
		elif (current_pc >= 11 ):
			current_pc -= 11;
			current_instruction += 18; next_pc += 10;
		elif (current_pc >= 10 ):
			current_pc -= 10;
			next_pc += 9; current_instruction += 3; var_pointer_offset += 1;
		elif (current_pc >= 9 ):
			current_pc -= 9;
			current_instruction += 34; next_pc += 8;
		elif (current_pc >= 8 ):
			current_pc -= 8;
			next_pc += 7; current_instruction += 26; jump_arg += 7;
		elif (current_pc >= 7 ):
			current_pc -= 7;
			current_instruction += 15; next_pc += 6;
		elif (current_pc >= 6 ):
			current_pc -= 6;
			current_instruction += 15; next_pc += 5;
		elif (current_pc >= 5 ):
			current_pc -= 5;
			current_instruction += 4; next_pc += 4;
		elif (current_pc >= 4 ):
			current_pc -= 4;
			current_instruction += 38; next_pc += 3;
		elif (current_pc >= 3 ):
			current_pc -= 3;
			current_instruction += 6; next_pc += 2;
		elif (current_pc >= 2 ):
			current_pc -= 2;
			current_instruction += 4; next_pc += 1;
		elif (current_pc >= 1 ):
			current_pc -= 1;
			current_instruction += 10; next_pc += 0;
		else:
			break;

	if (_stack_9 > 0):
		print("_stack_9", _stack_9);
	if (next_instruction_state > 0):
		print("next_instruction_state", next_instruction_state);
	if (_stack_pointer > 0):
		print("_stack_pointer", _stack_pointer);
	if (_stack_57 > 0):
		print("_stack_57", _stack_57);
	if (_stack_26 > 0):
		print("_stack_26", _stack_26);
	if (_stack_47 > 0):
		print("_stack_47", _stack_47);
	if (_stack_44 > 0):
		print("_stack_44", _stack_44);
	if (_pc_stack_7 > 0):
		print("_pc_stack_7", _pc_stack_7);
	if (_flag_equal > 0):
		print("_flag_equal", _flag_equal);
	if (_stack_21 > 0):
		print("_stack_21", _stack_21);
	if (_stack_16 > 0):
		print("_stack_16", _stack_16);
	if (_stack_24 > 0):
		print("_stack_24", _stack_24);
	if (_stack_43 > 0):
		print("_stack_43", _stack_43);
	if (_stack_13 > 0):
		print("_stack_13", _stack_13);
	if (_stack_4 > 0):
		print("_stack_4", _stack_4);
	if (_stack_3 > 0):
		print("_stack_3", _stack_3);
	if (_stack_36 > 0):
		print("_stack_36", _stack_36);
	if (_stack_64 > 0):
		print("_stack_64", _stack_64);
	if (ERROR_SUBTRACT_UNDERFLOW > 0):
		print("ERROR_SUBTRACT_UNDERFLOW", ERROR_SUBTRACT_UNDERFLOW);
	if (_stack_32 > 0):
		print("_stack_32", _stack_32);
	if (_next_var_pointer > 0):
		print("_next_var_pointer", _next_var_pointer);
	if (ERROR_PC_STACK_UNDERFLOW > 0):
		print("ERROR_PC_STACK_UNDERFLOW", ERROR_PC_STACK_UNDERFLOW);
	if (_stack_46 > 0):
		print("_stack_46", _stack_46);
	if (_stack_28 > 0):
		print("_stack_28", _stack_28);
	if (ERROR_BELOW_BOUNDS > 0):
		print("ERROR_BELOW_BOUNDS", ERROR_BELOW_BOUNDS);
	if (_stack_35 > 0):
		print("_stack_35", _stack_35);
	if (ERROR_VAR_POINTER_UNDERFLOW > 0):
		print("ERROR_VAR_POINTER_UNDERFLOW", ERROR_VAR_POINTER_UNDERFLOW);
	if (_stack_17 > 0):
		print("_stack_17", _stack_17);
	if (arg_one > 0):
		print("arg_one", arg_one);
	if (_stack_29 > 0):
		print("_stack_29", _stack_29);
	if (_stack_37 > 0):
		print("_stack_37", _stack_37);
	if (_pc_stack_4 > 0):
		print("_pc_stack_4", _pc_stack_4);
	if (current_instruction > 0):
		print("current_instruction", current_instruction);
	if (_stack_50 > 0):
		print("_stack_50", _stack_50);
	if (_stack_41 > 0):
		print("_stack_41", _stack_41);
	if (_stack_30 > 0):
		print("_stack_30", _stack_30);
	if (_stack_54 > 0):
		print("_stack_54", _stack_54);
	if (_holder_two > 0):
		print("_holder_two", _holder_two);
	if (arg_two > 0):
		print("arg_two", arg_two);
	if (_stack_7 > 0):
		print("_stack_7", _stack_7);
	if (var_pointer > 0):
		print("var_pointer", var_pointer);
	if (_stack_19 > 0):
		print("_stack_19", _stack_19);
	if (_pc_stack_14 > 0):
		print("_pc_stack_14", _pc_stack_14);
	if (_stack_61 > 0):
		print("_stack_61", _stack_61);
	if (ERROR_PC_STACK_OVERFLOW > 0):
		print("ERROR_PC_STACK_OVERFLOW", ERROR_PC_STACK_OVERFLOW);
	if (jump_arg > 0):
		print("jump_arg", jump_arg);
	if (_stack_58 > 0):
		print("_stack_58", _stack_58);
	if (_stack_22 > 0):
		print("_stack_22", _stack_22);
	if (ERROR_STACK_UNDERFLOW > 0):
		print("ERROR_STACK_UNDERFLOW", ERROR_STACK_UNDERFLOW);
	if (_pc_stack_1 > 0):
		print("_pc_stack_1", _pc_stack_1);
	if (current_pc > 0):
		print("current_pc", current_pc);
	if (_stack_53 > 0):
		print("_stack_53", _stack_53);
	if (_stack_40 > 0):
		print("_stack_40", _stack_40);
	if (_pc_stack_6 > 0):
		print("_pc_stack_6", _pc_stack_6);
	if (_pc_stack_pointer > 0):
		print("_pc_stack_pointer", _pc_stack_pointer);
	if (_pc_stack_12 > 0):
		print("_pc_stack_12", _pc_stack_12);
	if (_stack_14 > 0):
		print("_stack_14", _stack_14);
	if (ERROR_STACK_OVERFLOW > 0):
		print("ERROR_STACK_OVERFLOW", ERROR_STACK_OVERFLOW);
	if (_stack_38 > 0):
		print("_stack_38", _stack_38);
	if (_stack_62 > 0):
		print("_stack_62", _stack_62);
	if (_stack_48 > 0):
		print("_stack_48", _stack_48);
	if (_pc_stack_10 > 0):
		print("_pc_stack_10", _pc_stack_10);
	if (_pc_stack_11 > 0):
		print("_pc_stack_11", _pc_stack_11);
	if (_stack_6 > 0):
		print("_stack_6", _stack_6);
	if (_stack_20 > 0):
		print("_stack_20", _stack_20);
	if (_pc_stack_5 > 0):
		print("_pc_stack_5", _pc_stack_5);
	if (_pc_stack_15 > 0):
		print("_pc_stack_15", _pc_stack_15);
	if (stack_frame > 0):
		print("stack_frame", stack_frame);
	if (_stack_56 > 0):
		print("_stack_56", _stack_56);
	if (_stack_2 > 0):
		print("_stack_2", _stack_2);
	if (_stack_12 > 0):
		print("_stack_12", _stack_12);
	if (_next_stack_pointer > 0):
		print("_next_stack_pointer", _next_stack_pointer);
	if (instruction_state > 0):
		print("instruction_state", instruction_state);
	if (_stack_31 > 0):
		print("_stack_31", _stack_31);
	if (next_pc > 0):
		print("next_pc", next_pc);
	if (_stack_52 > 0):
		print("_stack_52", _stack_52);
	if (ERROR_DIVIDE_BY_ZERO > 0):
		print("ERROR_DIVIDE_BY_ZERO", ERROR_DIVIDE_BY_ZERO);
	if (_next_pc_stack_pointer > 0):
		print("_next_pc_stack_pointer", _next_pc_stack_pointer);
	if (_holder_one > 0):
		print("_holder_one", _holder_one);
	if (_pc_stack_9 > 0):
		print("_pc_stack_9", _pc_stack_9);
	if (_stack_1 > 0):
		print("_stack_1", _stack_1);
	if (_holder > 0):
		print("_holder", _holder);
	if (_stack_5 > 0):
		print("_stack_5", _stack_5);
	if (_stack_8 > 0):
		print("_stack_8", _stack_8);
	if (_stack_60 > 0):
		print("_stack_60", _stack_60);
	if (_stack_11 > 0):
		print("_stack_11", _stack_11);
	if (_stack_42 > 0):
		print("_stack_42", _stack_42);
	if (_stack_18 > 0):
		print("_stack_18", _stack_18);
	if (_pc_stack_13 > 0):
		print("_pc_stack_13", _pc_stack_13);
	if (_stack_15 > 0):
		print("_stack_15", _stack_15);
	if (_stack_49 > 0):
		print("_stack_49", _stack_49);
	if (_pc_stack_3 > 0):
		print("_pc_stack_3", _pc_stack_3);
	if (_stack_33 > 0):
		print("_stack_33", _stack_33);
	if (_stack_34 > 0):
		print("_stack_34", _stack_34);
	if (_stack_55 > 0):
		print("_stack_55", _stack_55);
	if (_stack_23 > 0):
		print("_stack_23", _stack_23);
	if (_stack_25 > 0):
		print("_stack_25", _stack_25);
	if (_stack_59 > 0):
		print("_stack_59", _stack_59);
	if (_stack_51 > 0):
		print("_stack_51", _stack_51);
	if (_stack_45 > 0):
		print("_stack_45", _stack_45);
	if (_pc_stack_8 > 0):
		print("_pc_stack_8", _pc_stack_8);
	if (_stack_39 > 0):
		print("_stack_39", _stack_39);
	if (_stack_10 > 0):
		print("_stack_10", _stack_10);
	if (var_pointer_offset > 0):
		print("var_pointer_offset", var_pointer_offset);
	if (ERROR_ABOVE_BOUNDS > 0):
		print("ERROR_ABOVE_BOUNDS", ERROR_ABOVE_BOUNDS);
	if (ERROR_DECREMENT_UNDERFLOW > 0):
		print("ERROR_DECREMENT_UNDERFLOW", ERROR_DECREMENT_UNDERFLOW);
	if (_pc_stack_2 > 0):
		print("_pc_stack_2", _pc_stack_2);
	if (next_instruction > 0):
		print("next_instruction", next_instruction);
	if (_stack_27 > 0):
		print("_stack_27", _stack_27);
	if (_stack_63 > 0):
		print("_stack_63", _stack_63);

	return 0;

main()
# Out:
# arg_one 233168
# 0

# %% [markdown]
# # 4. Regression Analysis
# California housing data
# https://scikit-learn.org/stable/datasets/real_world.html#california-housing-dataset

# %%
import numpy as numpy
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

# %%
# Load the California housing data
cal = fetch_california_housing(as_frame=True)
X, y = cal.data, cal.target
feature_names = X.columns
print(feature_names)


# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error

# %%
model = MLPRegressor(hidden_layer_sizes=(20,20 ), activation='relu', solver='adam', random_state=0, max_iter=500)
model.fit(X_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(20, 20), max_iter=500, random_state=0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

print(
    pd.DataFrame(
        zip(
            X.columns,
            numpy.multiply(
                model.coef_,
                pd.DataFrame.median(X_train).map(lambda x: 1/x)
            ).map(lambda x: round(x, 3))
        )
    )
)
# Out:
#             0      1
# 0      MedInc  0.122
# 1    HouseAge  0.000
# 2    AveRooms -0.019
# 3   AveBedrms  0.566
# 4  Population -0.000
# 5    AveOccup -0.002
# 6    Latitude -0.012
# 7   Longitude  0.004

# %%
y_pred = model.predict(X_test)

print("Root Mean Squared Error:", root_mean_squared_error(y_test, y_pred))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R-squared:", r2_score(y_test, y_pred))

plt.scatter(y_test, y_pred)
plt.xlabel("Actual Median House Value")
plt.ylabel("Predicted Median House Value")
plt.title("Linear Regression Result")
plt.show()

plt.hist(y_test - y_pred, bins=50)
plt.xlabel("Prediction Error")
plt.ylabel("Count")
plt.title("Prediction Error Distribution")
plt.show()
# Out:
# Root Mean Squared Error: 0.7273129773603114
# Mean Absolute Error: 0.535126133655451
# R-squared: 0.5943232652466202

# %% [markdown]
# # 5. Classification Analysis
# Diagnostic Wisconsin Breast Cancer Database
# https://scikit-learn.org/stable/datasets/toy_dataset.html#breast-cancer-dataset

# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Load Breast Cancer Wisconsin Dataset
data = load_breast_cancer(as_frame=True)
X = data.data
y = data.target                  # 0 = malignant, 1 = benign
feature_names = X.columns
label_names = {0: "malignant", 1: "benign"}
print(feature_names)

# Train/Test Split (stratified to preserve class balance)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0, stratify=y)

# Preprocess Data (fit on train ONLY; then transform both)
scaler = StandardScaler(with_mean=True, with_std=True)
X_train_std = scaler.fit_transform(X_train)   # fit on train
X_test_std  = scaler.transform(X_test)        # transform test with train stats
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension'],
#       dtype='object')

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, roc_auc_score, average_precision_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, precision_recall_curve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
model = SVC(kernel='linear', random_state=0, probability=True)

model.fit(X_train_std, y_train)

print(
    pd.DataFrame(
        zip(
            feature_names,
            model.coef_[0],
        )
    ).sort_values([1])
)
# Out:
#                           0         1
# 7       mean concave points -0.967260
# 10             radius error -0.944002
# 29  worst fractal dimension -0.917051
# 21            worst texture -0.908194
# 26          worst concavity -0.772508
# 6            mean concavity -0.650475
# 17     concave points error -0.634202
# 20             worst radius -0.628881
# 13               area error -0.611921
# 23               worst area -0.610313
# 24         worst smoothness -0.524760
# 28           worst symmetry -0.488805
# 3                 mean area -0.487837
# 22          worst perimeter -0.432630
# 0               mean radius -0.404961
# 2            mean perimeter -0.328945
# 12          perimeter error -0.312524
# 14         smoothness error -0.255790
# 27     worst concave points -0.244789
# 1              mean texture -0.192708
# 8             mean symmetry -0.107180
# 25        worst compactness  0.114945
# 4           mean smoothness  0.164633
# 16          concavity error  0.190326
# ...

# %%
model = DecisionTreeClassifier(random_state=0)
model.fit(X_train_std, y_train)

plt.figure(figsize=(20,10))
plot_tree(model, feature_names=X.columns, class_names=label_names , filled=True)
plt.show()

# %%
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train_std, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(X_test_std)
y_proba = model.predict_proba(X_test_std)[:, 1]

print("Train Accuracy:", model.score(X_train_std, y_train))
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_proba))
print("Average Precision:", average_precision_score(y_test, y_proba))


cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
print(cm)

fpr, tpr, _ = roc_curve(y_test, y_proba)
plt.plot(fpr, tpr, label='SVM (AUC = %0.2f)' % roc_auc_score(y_test, y_proba))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
3
precision, recall, _ = precision_recall_curve(y_test, y_proba)
plt.plot(recall, precision, label='SVM (AP = %0.2f)' % average_precision_score(y_test, y_proba))
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.show()
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.9385964912280702
# ROC AUC: 0.941468253968254
# Average Precision: 0.9474425798796509
# [[40  2]
#  [ 5 67]]
